# %%
# Dependencies
import os
import sys
import zipfile
import pandas as pd
import numpy as np
import shutil
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Read file to dataframe
file_path = os.path.join(".", "dataset", "city_file_list.csv")
df = pd.read_csv(file_path)
df.head()
# Out:
#         City                  File              New_Name  \
# 0   Chandler   my_mapChandler.html   my_mapChandler.html
# 1  Charlotte  my_mapCharlotte.html  my_mapCharlotte.html
# 2  Cleveland  my_mapCleveland.html  my_mapCleveland.html
# 3  Henderson  my_mapHenderson.html  my_mapHenderson.html
# 4  Las Vegas   my_mapLosVegas.html   my_mapLosVegas.html
#
#                              File_Path
# 0   static/graphic/my_mapChandler.html
# 1  static/graphic/my_mapCharlotte.html
# 2  static/graphic/my_mapCleveland.html
# 3  static/graphic/my_mapHenderson.html
# 4   static/graphic/my_mapLosVegas.html

# %%
# Loop thru each record, if extension is not html, search for file: if file exist, rename file
def Rename_Files():
    base_path = os.path.join(".", "graphic")

    for i, rw in df.iterrows():
        ext = os.path.splitext(rw.File)[1].lower()
        if not "html" in ext:
    #         print(rw.File)
    #         print(os.path.join(base_path, rw.File))
            if os.path.exists(os.path.join(base_path, rw.File)):
                print(rw.File)
    #             print(os.path.join(base_path, rw.File))
                os.rename(os.path.join(base_path, rw.File),os.path.join(base_path, rw.New_Name))

# %%
ilist = ["my_map", "leastStore", "TopStore", "review", "words", "rating", "categories"]
result_df = df.loc[(df["City"] == "Chandler")]  
result_df

# %%
r_list = {}
for i, rw in result_df.iterrows():
    for x in ilist:
        if x in rw.New_Name:
            r_list[x] = rw.File_Path

r_list

# %%
file_path = os.path.join(".", "dataset", "city_file_list.xlsx")
df = pd.read_excel(file_path)
r_list = []
r_list = df.City.unique()
r_list

# %%
for i in r_list:
    print(i)

# %%
df["Created_By"] = "Janie"
df["Created_Date"] = pd.datetime.now().strftime("%m-%d-%Y %I:%M:%S") 

df
# Out:
#           City                                        File  \
# 0     Chandler                         my_mapChandler.html
# 1    Charlotte                        my_mapCharlotte.html
# 2    Cleveland                        my_mapCleveland.html
# 3    Henderson                        my_mapHenderson.html
# 4    Las Vegas                         my_mapLosVegas.html
# 5         Mesa                             my_mapMesa.html
# 6      Phoenix                          my_mapPhoenix.html
# 7   Pittsburgh                       my_mapPittsburgh.html
# 8   Scottsdale                       my_mapScottsdale.html
# 9        Tempe                            my_mapTempe.html
# 10    Chandler    least Stores City and StatesChandler.png
# 11    Chandler      Top stores City and StatesChandler.png
# 12   Charlotte   least Stores City and StatesCharlotte.png
# 13   Charlotte     Top stores City and StatesCharlotte.png
# 14   Cleveland   least Stores City and StatesCleveland.png
# ...

# %%
# Set connection to database
from pymongo import MongoClient
client = MongoClient("mongodb+srv://admin:admin123@janie-test-vcn3t.mongodb.net/test?retryWrites=true")
db = client.consultant

# %%
records = df.to_dict('records')
[db.list.update_many({"City": row["City"], "File_Path": row["File_Path"]}, {'$set': row}, upsert=True) for row in records]

# %%
df = db.list.distinct("City")
df
# Out:
# ['Chandler',
#  'Charlotte',
#  'Cleveland',
#  'Henderson',
#  'Las Vegas',
#  'Mesa',
#  'Phoenix',
#  'Pittsburgh',
#  'Scottsdale',
#  'Tempe']

# %%
df = pd.DataFrame(db.list.find( { "City": "Chandler" }, {"_id": 0, "File_Path": 1}))
df
# Out:
#                                 File_Path                       _id
# 0      static/graphic/my_mapChandler.html  5cd3eeae652925c9dd257920
# 1  static/graphic/leastStoresChandler.png  5cd3eeaf652925c9dd257a3f
# 2    static/graphic/TopstoresChandler.png  5cd3eeaf652925c9dd257a5b
# 3       static/graphic/reviewChandler.png  5cd3eeaf652925c9dd257c07
# 4        static/graphic/wordsChandler.png  5cd3eeb0652925c9dd257d9f
# 5       static/graphic/RatingChandler.png  5cd3eeb0652925c9dd257ebb
# 6   static/graphic/categoriesChandler.png  5cd3eeb0652925c9dd257f48
