# %%
# Dependencies
import os
import sys
import re 
import pandas as pd
import numpy as np
from pymongo import MongoClient
import shutil
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Set directory file paths
filepath = os.path.join(".", "Resources/State/Demographic", "ACS_11_5YR_S0102_with_ann.csv")

# %%
total_state_df = pd.read_csv(filepath, skiprows=[0])
# Split the extension from the path and normalise it to lowercase.
# ext = os.path.splitext(filepath)[-1].lower()
# excel = os.path.splitext(filepath)[0].lower()

# state_df["Year"] = "2009"
# state_df["Year"] = int(excel.split("_")[-1])
total_state_df.head()
# Out:
#             Id  Id2   Geography  Total; Estimate; Total population  \
# 0  0400000US01    1     Alabama                            4850771
# 1  0400000US02    2      Alaska                             738565
# 2  0400000US04    4     Arizona                            6809946
# 3  0400000US05    5    Arkansas                            2977944
# 4  0400000US06    6  California                           38982847
#
#   Total; Margin of Error; Total population  \
# 0                                    *****
# 1                                    *****
# 2                                    *****
# 3                                    *****
# 4                                    *****
#
#    60 years and over; Estimate; Total population  \
# 0                                        1065625
# 1                                         117047
# 2                                        1502688
# 3                                         655552
# 4                                        7292299
#
#    60 years and over; Margin of Error; Total population  \
# 0                                               3368
# 1                                               1030
# 2                                               3385
# 3                                               2090
# 4                                               6791
#
#    Total; Estimate; SEX AND AGE - Male  \
# 0                                 48.5
# 1                                 52.3
# 2                                 49.7
# 3                                 49.1
# 4                                 49.7
#
#    Total; Margin of Error; SEX AND AGE - Male  \
# 0                                         0.1
# 1                                         0.1
# 2                                         0.1
# 3                                         0.1
# 4                                         0.1
#
#    60 years and over; Estimate; SEX AND AGE - Male  \
# 0                                             44.4
# 1                                             50.8
# 2                                             46.3
# 3                                             45.3
# 4                                             45.4
#
#                                        ...                                       \
# 0                                      ...
# 1                                      ...
# 2                                      ...
# 3                                      ...
# 4                                      ...
#
#    60 years and over; Estimate; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Less than 30 percent  \
# 0                                               55.2
# 1                                               56.5
# 2                                               48.3
# 3                                               56.6
# 4                                               40.0
#
#    60 years and over; Margin of Error; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Less than 30 percent  \
# 0                                                1.0
# 1                                                2.6
# 2                                                0.8
# 3                                                1.3
# 4                                                0.3
#
#    Total; Estimate; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                               42.6
# 1                                               41.6
# 2                                               45.2
# 3                                               40.7
# 4                                               53.1
#
#    Total; Margin of Error; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                                0.5
# 1                                                1.1
# 2                                                0.4
# 3                                                0.6
# 4                                                0.1
#
#    60 years and over; Estimate; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                               44.8
# 1                                               43.5
# 2                                               51.7
# 3                                               43.4
# 4                                               60.0
#
#    60 years and over; Margin of Error; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                                1.0
# 1                                                2.6
# 2                                                0.8
# 3                                                1.3
# 4                                                0.3
#
#    Total; Estimate; GROSS RENT - Median gross rent (dollars)  \
# 0                                                747
# 1                                               1200
# 2                                                972
# 3                                                709
# 4                                               1358
#
#    Total; Margin of Error; GROSS RENT - Median gross rent (dollars)  \
# 0                                                  3
# 1                                                 13
# 2                                                  4
# 3                                                  5
# 4                                                  3
#
#    60 years and over; Estimate; GROSS RENT - Median gross rent (dollars)  \
# 0                                                623
# 1                                                902
# 2                                                880
# 3                                                613
# 4                                               1109
#
#    60 years and over; Margin of Error; GROSS RENT - Median gross rent (dollars)
# 0                                                  8
# 1                                                 29
# 2                                                  8
# 3                                                  9
# 4                                                  4
#
# [5 rows x 427 columns]

# %%
edu_state_cols_df = total_state_df.filter(regex="Total; Estimate; EDUCATIONAL ATTAINMENT")
edu_state_df = total_state_df.filter(regex="Geography")

edu_state_df.head()
edu_state_cols_df.head()
# Out:
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over  \
# 0                                            3276637
# 1                                             475442
# 2                                            4516175
# 3                                            1985770
# 4                                           25950818
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than high school graduate  \
# 0                                               14.7
# 1                                                7.6
# 2                                               13.5
# 3                                               14.4
# 4                                               17.5
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate, GED, or alternative  \
# 0                                               30.9
# 1                                               27.6
# 2                                               24.2
# 3                                               34.3
# 4                                               20.6
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college or associate's degree  \
# 0                                               29.9
# 1                                               35.8
# 2                                               33.9
# 3                                               29.2
# 4                                               29.3
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher
# 0                                               24.5
# 1                                               29.0
# 2                                               28.4
# 3                                               22.0
# 4                                               32.6

# %%
total_edu_state_df = pd.concat([edu_state_df, edu_state_cols_df], axis=1)

total_edu_state_df.head()
# Out:
#     Geography  \
# 0     Alabama
# 1      Alaska
# 2     Arizona
# 3    Arkansas
# 4  California
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over  \
# 0                                            3276637
# 1                                             475442
# 2                                            4516175
# 3                                            1985770
# 4                                           25950818
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than high school graduate  \
# 0                                               14.7
# 1                                                7.6
# 2                                               13.5
# 3                                               14.4
# 4                                               17.5
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate, GED, or alternative  \
# 0                                               30.9
# 1                                               27.6
# 2                                               24.2
# 3                                               34.3
# 4                                               20.6
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college or associate's degree  \
# 0                                               29.9
# 1                                               35.8
# 2                                               33.9
# 3                                               29.2
# 4                                               29.3
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher
# 0                                               24.5
# 1                                               29.0
# 2                                               28.4
# 3                                               22.0
# 4                                               32.6

# %%
total_edu_state_df["Year"] = "2017"
# state_df["Year"] = int(excel.split("_")[-1])
total_edu_state_df.head()
# Out:
#     Geography  \
# 0     Alabama
# 1      Alaska
# 2     Arizona
# 3    Arkansas
# 4  California
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over  \
# 0                                            3276637
# 1                                             475442
# 2                                            4516175
# 3                                            1985770
# 4                                           25950818
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than high school graduate  \
# 0                                               14.7
# 1                                                7.6
# 2                                               13.5
# 3                                               14.4
# 4                                               17.5
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate, GED, or alternative  \
# 0                                               30.9
# 1                                               27.6
# 2                                               24.2
# 3                                               34.3
# 4                                               20.6
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college or associate's degree  \
# 0                                               29.9
# 1                                               35.8
# 2                                               33.9
# 3                                               29.2
# 4                                               29.3
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher  \
# 0                                               24.5
# 1                                               29.0
# 2                                               28.4
# 3                                               22.0
# 4                                               32.6
#
#    Year
# 0  2017
# 1  2017
# 2  2017
# 3  2017
# 4  2017

# %%
# Pass sheet title to description & country to hierachy columns for each row
total_edu_state_df["Hierarchy"] = "State"
# state_df["H_Name"] = list(state_df)[2]
# state_df["Population_Number"] = list(state_df)[3]
total_edu_state_df["Category"] = "Education"
total_edu_state_df["SubCategory"] = "25+yrs & over"
total_edu_state_df["Description"] = "Percentage(Float)"
total_edu_state_df["Notes"] = "Bachelor's degree or higher"

# Rename 1st two columns
mapping = {total_edu_state_df.columns[0]: 'H_Name', total_edu_state_df.columns[5]: 'Population_Number'}
state_df = total_edu_state_df.rename(columns=mapping)

state_df.head()
# Out:
#        H_Name  \
# 0     Alabama
# 1      Alaska
# 2     Arizona
# 3    Arkansas
# 4  California
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over  \
# 0                                            3276637
# 1                                             475442
# 2                                            4516175
# 3                                            1985770
# 4                                           25950818
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than high school graduate  \
# 0                                               14.7
# 1                                                7.6
# 2                                               13.5
# 3                                               14.4
# 4                                               17.5
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate, GED, or alternative  \
# 0                                               30.9
# 1                                               27.6
# 2                                               24.2
# 3                                               34.3
# 4                                               20.6
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college or associate's degree  \
# 0                                               29.9
# 1                                               35.8
# 2                                               33.9
# 3                                               29.2
# 4                                               29.3
#
#    Population_Number  Year Hierarchy   Category    SubCategory  \
# 0               24.5  2017     State  Education  25+yrs & over
# 1               29.0  2017     State  Education  25+yrs & over
# 2               28.4  2017     State  Education  25+yrs & over
# 3               22.0  2017     State  Education  25+yrs & over
# 4               32.6  2017     State  Education  25+yrs & over
#
#          Description                        Notes
# 0  Percentage(Float)  Bachelor's degree or higher
# 1  Percentage(Float)  Bachelor's degree or higher
# 2  Percentage(Float)  Bachelor's degree or higher
# 3  Percentage(Float)  Bachelor's degree or higher
# 4  Percentage(Float)  Bachelor's degree or higher

# %%
state_df.columns
# Out:
# Index(['H_Name',
#        'Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over',
#        'Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than high school graduate',
#        'Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate, GED, or alternative',
#        'Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college or associate's degree',
#        'Population_Number', 'Year', 'Hierarchy', 'Category', 'SubCategory',
#        'Description', 'Notes'],
#       dtype='object')

# %%
final_state_df = state_df[['Year', 'Hierarchy', 'H_Name', 'Population_Number', 'Category', 'SubCategory', 'Description', 'Notes']]
final_state_df.head()
# Out:
#    Year Hierarchy      H_Name  Population_Number   Category    SubCategory  \
# 0  2017     State     Alabama               24.5  Education  25+yrs & over
# 1  2017     State      Alaska               29.0  Education  25+yrs & over
# 2  2017     State     Arizona               28.4  Education  25+yrs & over
# 3  2017     State    Arkansas               22.0  Education  25+yrs & over
# 4  2017     State  California               32.6  Education  25+yrs & over
#
#          Description                        Notes
# 0  Percentage(Float)  Bachelor's degree or higher
# 1  Percentage(Float)  Bachelor's degree or higher
# 2  Percentage(Float)  Bachelor's degree or higher
# 3  Percentage(Float)  Bachelor's degree or higher
# 4  Percentage(Float)  Bachelor's degree or higher

# %%
# This function move footnotes to specific cells and remove Nan rows
def Update_FootNotes(_df):
    _df["Notes"] = "" 
    # Get all the 1st character in column, extract only digit & get the max    
    nlist = _df['Notes'].str[0].tolist()
    results = [int(n) for n in nlist if n.isdigit()]
    m = max(results)
    f = m
    # Loop thru the max and update footnote to specific row cell
    for i in range(m):
        n = (i+1)
        fn = f'-{f}'
        #         print(n)
        #         print(fn)
        footnote = _df.iloc[int(fn), 0].replace(f"{n} ", "")
#         print(footnote)
        _df.loc[_df.Notes.str.contains(str(n)), "Notes"] = f'Footnotes {n}: {footnote}'
        f-=1
    # -----------------------------------------------    
    # Drop all NaN rows
    _df = _df.dropna()
    # Remove digit from column
    pattern = '[0-9]'
    _df.Notes = [re.sub(pattern, '', row.Notes) for i, row in _df.iterrows()] 
        
    return _df

# %%
# Pass footnote to specific cells and clean data
# state_df = Update_FootNotes(state_df)
# Convert Column to Integer
# state_df[""] = state_df[""].astype(int)
# Some excel sheet has lowercase
# state_df.loc[state_df[""] == "", ""] = ""
# state_df.reset_index(drop=True,inplace=True)

# %%
final_state_df["Created_By"] = "Charleen"
final_state_df["Created_Date"] = pd.datetime.now().strftime("%m-%d-%Y %I:%M:%S")
final_state_df.head()
# Out:
#    Year Hierarchy      H_Name  Population_Number   Category    SubCategory  \
# 0  2017     State     Alabama               24.5  Education  25+yrs & over
# 1  2017     State      Alaska               29.0  Education  25+yrs & over
# 2  2017     State     Arizona               28.4  Education  25+yrs & over
# 3  2017     State    Arkansas               22.0  Education  25+yrs & over
# 4  2017     State  California               32.6  Education  25+yrs & over
#
#          Description                        Notes Created_By  \
# 0  Percentage(Float)  Bachelor's degree or higher   Charleen
# 1  Percentage(Float)  Bachelor's degree or higher   Charleen
# 2  Percentage(Float)  Bachelor's degree or higher   Charleen
# 3  Percentage(Float)  Bachelor's degree or higher   Charleen
# 4  Percentage(Float)  Bachelor's degree or higher   Charleen
#
#           Created_Date
# 0  05-05-2019 01:21:50
# 1  05-05-2019 01:21:50
# 2  05-05-2019 01:21:50
# 3  05-05-2019 01:21:50
# 4  05-05-2019 01:21:50

# %%
# # Create notes column and copy footnotes to Notes for selective row by locating the row cell with the footnote
# country_df["Notes"] = ""      
# country_df.loc[country_df.Crime_Type.str.contains('1'), "Notes"] = f'Footnotes: {country_df.iloc[-2, 0].replace("1 ", "")}'
# country_df.loc[country_df.Crime_Type.str.contains('2'), "Notes"] = f'Footnotes: {country_df.iloc[-1, 0].replace("2 ", "")}'
# # Drop all NaN rows
# country_df = country_df.dropna()
# # Remove digit from column
# pattern = '[0-9]'
# country_df.Crime_Type = [re.sub(pattern, '', row.Crime_Type) for i, row in country_df.iterrows()] 
final_state_df.count()
# Out:
# Year                 51
# Hierarchy            51
# H_Name               51
# Population_Number    51
# Category             51
# SubCategory          51
# Description          51
# Notes                51
# Created_By           51
# Created_Date         51
# dtype: int64

# %%
final_state_df.dtypes
# Out:
# Year                  object
# Hierarchy             object
# H_Name                object
# Population_Number    float64
# Category              object
# SubCategory           object
# Description           object
# Notes                 object
# Created_By            object
# Created_Date          object
# dtype: object

# %%
final_state_df['Year'] = final_state_df['Year'].astype(int)

# %%
final_state_df = final_state_df.astype({'Year': 'int64'})

# %%
final_state_df.dtypes
# Out:
# Year                   int64
# Hierarchy             object
# H_Name                object
# Population_Number    float64
# Category              object
# SubCategory           object
# Description           object
# Notes                 object
# Created_By            object
# Created_Date          object
# dtype: object

# %%
final_state_df['H_Name'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
len(final_state_df['H_Name'].unique())
# Out:
# 51

# %%
final_state_df.shape
# Out:
# (51, 10)

# %%
final_state_df.describe()
# Out:
#          Year  Population_Number
# count    51.0          51.000000
# mean   2017.0          30.633333
# std       0.0           6.229917
# min    2017.0          19.900000
# 25%    2017.0          26.950000
# 50%    2017.0          29.900000
# 75%    2017.0          33.200000
# max    2017.0          56.600000

# %%
# Set connection to database
client = MongoClient("mongodb+srv://admin:admin123@janie-test-vcn3t.mongodb.net/test?retryWrites=true")
db = client.consultant

# %%
records = final_state_df.to_dict('records')
[db.population.update_many({"Year": row["Year"], "Hierarchy": row["Hierarchy"], "H_Name": row["H_Name"], "Population_Number": row["Population_Number"], "Category": row["Category"], "SubCategory": row["SubCategory"], "Description": row["Description"], "Notes": row["Notes"], "Created_By": row["Created_By"], "Created_Date": row["Created_Date"]}, {'$set': row}, upsert=True) for row in records]
# Out:
# [<pymongo.results.UpdateResult at 0x1ceac16f0c8>,
#  <pymongo.results.UpdateResult at 0x1ceac19fb48>,
#  <pymongo.results.UpdateResult at 0x1ceabfda248>,
#  <pymongo.results.UpdateResult at 0x1ceabef4988>,
#  <pymongo.results.UpdateResult at 0x1ceac18d588>,
#  <pymongo.results.UpdateResult at 0x1ceac0f90c8>,
#  <pymongo.results.UpdateResult at 0x1ceac0f99c8>,
#  <pymongo.results.UpdateResult at 0x1ceabff8688>,
#  <pymongo.results.UpdateResult at 0x1ceabff8308>,
#  <pymongo.results.UpdateResult at 0x1ceac106c88>,
#  <pymongo.results.UpdateResult at 0x1ceac0e2d08>,
#  <pymongo.results.UpdateResult at 0x1ceac0ee148>,
#  <pymongo.results.UpdateResult at 0x1ceac0fccc8>,
#  <pymongo.results.UpdateResult at 0x1ceac1561c8>,
#  <pymongo.results.UpdateResult at 0x1ceac16afc8>,
#  <pymongo.results.UpdateResult at 0x1ceac174288>,
#  <pymongo.results.UpdateResult at 0x1ceac0cf808>,
#  <pymongo.results.UpdateResult at 0x1ceabfdc188>,
#  <pymongo.results.UpdateResult at 0x1ceac0c3cc8>,
#  <pymongo.results.UpdateResult at 0x1ceac0cdd08>,
#  <pymongo.results.UpdateResult at 0x1ceabdde0c8>,
#  <pymongo.results.UpdateResult at 0x1ceac0e4b88>,
#  <pymongo.results.UpdateResult at 0x1ceac15cac8>,
#  <pymongo.results.UpdateResult at 0x1ceac15fec8>,
#  <pymongo.results.UpdateResult at 0x1ceac164b48>,
#  <pymongo.results.UpdateResult at 0x1ceac1693c8>,
#  <pymongo.results.UpdateResult at 0x1ceac1e4308>,
#  <pymongo.results.UpdateResult at 0x1ceac1e8408>,
#  <pymongo.results.UpdateResult at 0x1ceac1ead88>,
#  <pymongo.results.UpdateResult at 0x1ceac1eee48>,
#  <pymongo.results.UpdateResult at 0x1ceac1f50c8>,
#  <pymongo.results.UpdateResult at 0x1ceac1fec48>,
#  <pymongo.results.UpdateResult at 0x1ceac1ff348>,
#  <pymongo.results.UpdateResult at 0x1ceac205588>,
#  <pymongo.results.UpdateResult at 0x1ceac2086c8>,
#  <pymongo.results.UpdateResult at 0x1ceac20b288>,
#  <pymongo.results.UpdateResult at 0x1ceac212508>,
#  <pymongo.results.UpdateResult at 0x1ceac21aa08>,
#  <pymongo.results.UpdateResult at 0x1ceac21cfc8>,
#  <pymongo.results.UpdateResult at 0x1ceac222508>,
#  <pymongo.results.UpdateResult at 0x1ceac2260c8>,
#  <pymongo.results.UpdateResult at 0x1ceac228a88>,
#  <pymongo.results.UpdateResult at 0x1ceac22df88>,
#  <pymongo.results.UpdateResult at 0x1ceac22f708>,
#  <pymongo.results.UpdateResult at 0x1ceac235e88>,
#  <pymongo.results.UpdateResult at 0x1ceac237208>,
#  <pymongo.results.UpdateResult at 0x1ceac23d208>,
#  <pymongo.results.UpdateResult at 0x1ceac23f548>,
#  <pymongo.results.UpdateResult at 0x1ceac247c08>,
#  <pymongo.results.UpdateResult at 0x1ceac248808>,
#  <pymongo.results.UpdateResult at 0x1ceac242708>]

# %%
# Get data from mongo & convert back to dataframe
df = pd.DataFrame.from_records(db.population.find({}, {'_id': 0 }))
df
# Out:
#         Category Created_By         Created_Date        Description  \
# 0     Population   Charleen  05-05-2019 08:11:08            Integer
# 1     Population   Charleen  05-05-2019 08:11:08            Integer
# 2     Population   Charleen  05-05-2019 08:11:08            Integer
# 3     Population   Charleen  05-05-2019 08:11:08            Integer
# 4     Population   Charleen  05-05-2019 08:11:08            Integer
# 5     Population   Charleen  05-05-2019 08:11:08            Integer
# 6     Population   Charleen  05-05-2019 08:11:08            Integer
# 7     Population   Charleen  05-05-2019 08:11:08            Integer
# 8     Population   Charleen  05-05-2019 08:11:08            Integer
# 9     Population   Charleen  05-05-2019 08:11:08            Integer
# 10    Population   Charleen  05-05-2019 08:11:08            Integer
# 11    Population   Charleen  05-05-2019 08:11:08            Integer
# 12    Population   Charleen  05-05-2019 08:11:08            Integer
# 13    Population   Charleen  05-05-2019 08:11:08            Integer
# 14    Population   Charleen  05-05-2019 08:11:08            Integer
# 15    Population   Charleen  05-05-2019 08:11:08            Integer
# 16    Population   Charleen  05-05-2019 08:11:08            Integer
# 17    Population   Charleen  05-05-2019 08:11:08            Integer
# 18    Population   Charleen  05-05-2019 08:11:08            Integer
# 19    Population   Charleen  05-05-2019 08:11:08            Integer
# 20    Population   Charleen  05-05-2019 08:11:08            Integer
# 21    Population   Charleen  05-05-2019 08:11:08            Integer
# 22    Population   Charleen  05-05-2019 08:11:08            Integer
# 23    Population   Charleen  05-05-2019 08:11:08            Integer
# 24    Population   Charleen  05-05-2019 08:11:08            Integer
# 25    Population   Charleen  05-05-2019 08:11:08            Integer
# 26    Population   Charleen  05-05-2019 08:11:08            Integer
# 27    Population   Charleen  05-05-2019 08:11:08            Integer
# 28    Population   Charleen  05-05-2019 08:11:08            Integer
# 29    Population   Charleen  05-05-2019 08:11:08            Integer
# ...          ...        ...                  ...                ...
# 3642   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3643   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3644   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3645   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3646   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3647   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3648   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3649   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3650   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3651   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3652   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3653   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3654   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3655   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3656   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3657   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3658   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3659   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3660   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3661   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3662   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3663   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3664   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3665   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3666   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3667   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3668   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3669   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3670   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
# 3671   Education   Charleen  05-05-2019 01:21:50  Percentage(Float)
#
#                     H_Name Hierarchy                        Notes  \
# 0                  Alabama     State
# 1                   Alaska     State
# 2                  Arizona     State
# 3                 Arkansas     State
# 4               California     State
# 5                 Colorado     State
# 6              Connecticut     State
# 7                 Delaware     State
# 8     District of Columbia     State
# 9                  Florida     State
# 10                 Georgia     State
# 11                  Hawaii     State
# 12                   Idaho     State
# 13                Illinois     State
# 14                 Indiana     State
# 15                    Iowa     State
# 16                  Kansas     State
# 17                Kentucky     State
# 18               Louisiana     State
# 19                   Maine     State
# 20                Maryland     State
# 21           Massachusetts     State
# 22                Michigan     State
# 23               Minnesota     State
# 24             Mississippi     State
# 25                Missouri     State
# 26                 Montana     State
# 27                Nebraska     State
# 28                  Nevada     State
# 29           New Hampshire     State
# ...                    ...       ...                          ...
# 3642         Massachusetts     State  Bachelor's degree or higher
# 3643              Michigan     State  Bachelor's degree or higher
# 3644             Minnesota     State  Bachelor's degree or higher
# 3645           Mississippi     State  Bachelor's degree or higher
# 3646              Missouri     State  Bachelor's degree or higher
# 3647               Montana     State  Bachelor's degree or higher
# 3648              Nebraska     State  Bachelor's degree or higher
# 3649                Nevada     State  Bachelor's degree or higher
# 3650         New Hampshire     State  Bachelor's degree or higher
# 3651            New Jersey     State  Bachelor's degree or higher
# 3652            New Mexico     State  Bachelor's degree or higher
# 3653              New York     State  Bachelor's degree or higher
# 3654        North Carolina     State  Bachelor's degree or higher
# 3655          North Dakota     State  Bachelor's degree or higher
# 3656                  Ohio     State  Bachelor's degree or higher
# 3657              Oklahoma     State  Bachelor's degree or higher
# 3658                Oregon     State  Bachelor's degree or higher
# 3659          Pennsylvania     State  Bachelor's degree or higher
# 3660          Rhode Island     State  Bachelor's degree or higher
# 3661        South Carolina     State  Bachelor's degree or higher
# 3662          South Dakota     State  Bachelor's degree or higher
# 3663             Tennessee     State  Bachelor's degree or higher
# 3664                 Texas     State  Bachelor's degree or higher
# 3665                  Utah     State  Bachelor's degree or higher
# 3666               Vermont     State  Bachelor's degree or higher
# 3667              Virginia     State  Bachelor's degree or higher
# 3668            Washington     State  Bachelor's degree or higher
# 3669         West Virginia     State  Bachelor's degree or higher
# 3670             Wisconsin     State  Bachelor's degree or higher
# 3671               Wyoming     State  Bachelor's degree or higher
#
#       Population_Number    SubCategory  Year
# 0             4633360.0          Total  2009
# 1              683142.0          Total  2009
# 2             6324865.0          Total  2009
# 3             2838143.0          Total  2009
# 4            36308527.0          Total  2009
# 5             4843211.0          Total  2009
# 6             3494487.0          Total  2009
# 7              863832.0          Total  2009
# 8              588433.0          Total  2009
# 9            18222420.0          Total  2009
# 10            9497667.0          Total  2009
# 11            1280241.0          Total  2009
# 12            1492573.0          Total  2009
# 13           12785043.0          Total  2009
# 14            6342469.0          Total  2009
# 15            2978880.0          Total  2009
# 16            2777835.0          Total  2009
# 17            4252000.0          Total  2009
# 18            4411546.0          Total  2009
# 19            1316380.0          Total  2009
# 20            5637418.0          Total  2009
# 21            6511176.0          Total  2009
# 22           10039208.0          Total  2009
# 23            5188581.0          Total  2009
# 24            2922240.0          Total  2009
# 25            5904382.0          Total  2009
# 26             956257.0          Total  2009
# 27            1772124.0          Total  2009
# 28            2545763.0          Total  2009
# 29            1315419.0          Total  2009
# ...                 ...            ...   ...
# 3642               42.1  25+yrs & over  2017
# 3643               28.1  25+yrs & over  2017
# 3644               34.8  25+yrs & over  2017
# 3645               21.3  25+yrs & over  2017
# 3646               28.2  25+yrs & over  2017
# 3647               30.7  25+yrs & over  2017
# 3648               30.6  25+yrs & over  2017
# 3649               23.7  25+yrs & over  2017
# 3650               36.0  25+yrs & over  2017
# 3651               38.1  25+yrs & over  2017
# 3652               26.9  25+yrs & over  2017
# 3653               35.3  25+yrs & over  2017
# 3654               29.9  25+yrs & over  2017
# 3655               28.9  25+yrs & over  2017
# 3656               27.2  25+yrs & over  2017
# 3657               24.8  25+yrs & over  2017
# 3658               32.3  25+yrs & over  2017
# 3659               30.1  25+yrs & over  2017
# 3660               33.0  25+yrs & over  2017
# 3661               27.0  25+yrs & over  2017
# 3662               27.8  25+yrs & over  2017
# 3663               26.1  25+yrs & over  2017
# 3664               28.7  25+yrs & over  2017
# 3665               32.5  25+yrs & over  2017
# 3666               36.8  25+yrs & over  2017
# 3667               37.6  25+yrs & over  2017
# 3668               34.5  25+yrs & over  2017
# 3669               19.9  25+yrs & over  2017
# 3670               29.0  25+yrs & over  2017
# 3671               26.7  25+yrs & over  2017
#
# [3672 rows x 10 columns]

# %%
# db.population.drop()
