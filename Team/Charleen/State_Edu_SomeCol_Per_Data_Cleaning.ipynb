# %%
# Dependencies
import os
import sys
import re 
import pandas as pd
import numpy as np
from pymongo import MongoClient
import shutil
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Set directory file paths
filepath = os.path.join(".", "Resources/State/Demographic", "ACS_17_5YR_S0102_with_ann.csv")

# %%
total_state_df = pd.read_csv(filepath, skiprows=[0])
# Split the extension from the path and normalise it to lowercase.
# ext = os.path.splitext(filepath)[-1].lower()
# excel = os.path.splitext(filepath)[0].lower()

# state_df["Year"] = "2009"
# state_df["Year"] = int(excel.split("_")[-1])
total_state_df.head()
# Out:
#             Id  Id2   Geography  Total; Estimate; Total population  \
# 0  0400000US01    1     Alabama                            4850771
# 1  0400000US02    2      Alaska                             738565
# 2  0400000US04    4     Arizona                            6809946
# 3  0400000US05    5    Arkansas                            2977944
# 4  0400000US06    6  California                           38982847
#
#   Total; Margin of Error; Total population  \
# 0                                    *****
# 1                                    *****
# 2                                    *****
# 3                                    *****
# 4                                    *****
#
#    60 years and over; Estimate; Total population  \
# 0                                        1065625
# 1                                         117047
# 2                                        1502688
# 3                                         655552
# 4                                        7292299
#
#    60 years and over; Margin of Error; Total population  \
# 0                                               3368
# 1                                               1030
# 2                                               3385
# 3                                               2090
# 4                                               6791
#
#    Total; Estimate; SEX AND AGE - Male  \
# 0                                 48.5
# 1                                 52.3
# 2                                 49.7
# 3                                 49.1
# 4                                 49.7
#
#    Total; Margin of Error; SEX AND AGE - Male  \
# 0                                         0.1
# 1                                         0.1
# 2                                         0.1
# 3                                         0.1
# 4                                         0.1
#
#    60 years and over; Estimate; SEX AND AGE - Male  \
# 0                                             44.4
# 1                                             50.8
# 2                                             46.3
# 3                                             45.3
# 4                                             45.4
#
#                                        ...                                       \
# 0                                      ...
# 1                                      ...
# 2                                      ...
# 3                                      ...
# 4                                      ...
#
#    60 years and over; Estimate; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Less than 30 percent  \
# 0                                               55.2
# 1                                               56.5
# 2                                               48.3
# 3                                               56.6
# 4                                               40.0
#
#    60 years and over; Margin of Error; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Less than 30 percent  \
# 0                                                1.0
# 1                                                2.6
# 2                                                0.8
# 3                                                1.3
# 4                                                0.3
#
#    Total; Estimate; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                               42.6
# 1                                               41.6
# 2                                               45.2
# 3                                               40.7
# 4                                               53.1
#
#    Total; Margin of Error; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                                0.5
# 1                                                1.1
# 2                                                0.4
# 3                                                0.6
# 4                                                0.1
#
#    60 years and over; Estimate; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                               44.8
# 1                                               43.5
# 2                                               51.7
# 3                                               43.4
# 4                                               60.0
#
#    60 years and over; Margin of Error; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                                1.0
# 1                                                2.6
# 2                                                0.8
# 3                                                1.3
# 4                                                0.3
#
#    Total; Estimate; GROSS RENT - Median gross rent (dollars)  \
# 0                                                747
# 1                                               1200
# 2                                                972
# 3                                                709
# 4                                               1358
#
#    Total; Margin of Error; GROSS RENT - Median gross rent (dollars)  \
# 0                                                  3
# 1                                                 13
# 2                                                  4
# 3                                                  5
# 4                                                  3
#
#    60 years and over; Estimate; GROSS RENT - Median gross rent (dollars)  \
# 0                                                623
# 1                                                902
# 2                                                880
# 3                                                613
# 4                                               1109
#
#    60 years and over; Margin of Error; GROSS RENT - Median gross rent (dollars)
# 0                                                  8
# 1                                                 29
# 2                                                  8
# 3                                                  9
# 4                                                  4
#
# [5 rows x 427 columns]

# %%
edu_state_cols_df = total_state_df.filter(regex="Total; Estimate; EDUCATIONAL ATTAINMENT")
edu_state_df = total_state_df.filter(regex="Geography")

edu_state_df.head()
edu_state_cols_df.head()
# Out:
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over  \
# 0                                            3276637
# 1                                             475442
# 2                                            4516175
# 3                                            1985770
# 4                                           25950818
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than high school graduate  \
# 0                                               14.7
# 1                                                7.6
# 2                                               13.5
# 3                                               14.4
# 4                                               17.5
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate, GED, or alternative  \
# 0                                               30.9
# 1                                               27.6
# 2                                               24.2
# 3                                               34.3
# 4                                               20.6
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college or associate's degree  \
# 0                                               29.9
# 1                                               35.8
# 2                                               33.9
# 3                                               29.2
# 4                                               29.3
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher
# 0                                               24.5
# 1                                               29.0
# 2                                               28.4
# 3                                               22.0
# 4                                               32.6

# %%
total_edu_state_df = pd.concat([edu_state_df, edu_state_cols_df], axis=1)

total_edu_state_df.head()
# Out:
#     Geography  \
# 0     Alabama
# 1      Alaska
# 2     Arizona
# 3    Arkansas
# 4  California
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over  \
# 0                                            3276637
# 1                                             475442
# 2                                            4516175
# 3                                            1985770
# 4                                           25950818
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than high school graduate  \
# 0                                               14.7
# 1                                                7.6
# 2                                               13.5
# 3                                               14.4
# 4                                               17.5
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate, GED, or alternative  \
# 0                                               30.9
# 1                                               27.6
# 2                                               24.2
# 3                                               34.3
# 4                                               20.6
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college or associate's degree  \
# 0                                               29.9
# 1                                               35.8
# 2                                               33.9
# 3                                               29.2
# 4                                               29.3
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher
# 0                                               24.5
# 1                                               29.0
# 2                                               28.4
# 3                                               22.0
# 4                                               32.6

# %%
total_edu_state_df["Year"] = "2017"
# state_df["Year"] = int(excel.split("_")[-1])
total_edu_state_df.head()
# Out:
#     Geography  \
# 0     Alabama
# 1      Alaska
# 2     Arizona
# 3    Arkansas
# 4  California
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over  \
# 0                                            3276637
# 1                                             475442
# 2                                            4516175
# 3                                            1985770
# 4                                           25950818
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than high school graduate  \
# 0                                               14.7
# 1                                                7.6
# 2                                               13.5
# 3                                               14.4
# 4                                               17.5
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate, GED, or alternative  \
# 0                                               30.9
# 1                                               27.6
# 2                                               24.2
# 3                                               34.3
# 4                                               20.6
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college or associate's degree  \
# 0                                               29.9
# 1                                               35.8
# 2                                               33.9
# 3                                               29.2
# 4                                               29.3
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher  \
# 0                                               24.5
# 1                                               29.0
# 2                                               28.4
# 3                                               22.0
# 4                                               32.6
#
#    Year
# 0  2017
# 1  2017
# 2  2017
# 3  2017
# 4  2017

# %%
# Pass sheet title to description & country to hierachy columns for each row
total_edu_state_df["Hierarchy"] = "State"
# state_df["H_Name"] = list(state_df)[2]
# state_df["Population_Number"] = list(state_df)[3]
total_edu_state_df["Category"] = "Education"
total_edu_state_df["SubCategory"] = "25+yrs & over"
total_edu_state_df["Description"] = "Percentage(Float)"
total_edu_state_df["Notes"] = "Some college or associate's degree"

# Rename 1st two columns
mapping = {total_edu_state_df.columns[0]: 'H_Name', total_edu_state_df.columns[4]: 'Population_Number'}
state_df = total_edu_state_df.rename(columns=mapping)

state_df.head()
# Out:
#        H_Name  \
# 0     Alabama
# 1      Alaska
# 2     Arizona
# 3    Arkansas
# 4  California
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over  \
# 0                                            3276637
# 1                                             475442
# 2                                            4516175
# 3                                            1985770
# 4                                           25950818
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than high school graduate  \
# 0                                               14.7
# 1                                                7.6
# 2                                               13.5
# 3                                               14.4
# 4                                               17.5
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate, GED, or alternative  \
# 0                                               30.9
# 1                                               27.6
# 2                                               24.2
# 3                                               34.3
# 4                                               20.6
#
#    Population_Number  \
# 0               29.9
# 1               35.8
# 2               33.9
# 3               29.2
# 4               29.3
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher  \
# 0                                               24.5
# 1                                               29.0
# 2                                               28.4
# 3                                               22.0
# 4                                               32.6
#
#    Year Hierarchy   Category    SubCategory        Description  \
# 0  2017     State  Education  25+yrs & over  Percentage(Float)
# 1  2017     State  Education  25+yrs & over  Percentage(Float)
# 2  2017     State  Education  25+yrs & over  Percentage(Float)
# 3  2017     State  Education  25+yrs & over  Percentage(Float)
# 4  2017     State  Education  25+yrs & over  Percentage(Float)
#
#                                 Notes
# 0  Some college or associate's degree
# 1  Some college or associate's degree
# 2  Some college or associate's degree
# 3  Some college or associate's degree
# 4  Some college or associate's degree

# %%
state_df.columns
# Out:
# Index(['H_Name',
#        'Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over',
#        'Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than high school graduate',
#        'Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate, GED, or alternative',
#        'Population_Number',
#        'Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher',
#        'Year', 'Hierarchy', 'Category', 'SubCategory', 'Description', 'Notes'],
#       dtype='object')

# %%
final_state_df = state_df[['Year', 'Hierarchy', 'H_Name', 'Population_Number', 'Category', 'SubCategory', 'Description', 'Notes']]
final_state_df.head()
# Out:
#    Year Hierarchy      H_Name  Population_Number   Category    SubCategory  \
# 0  2017     State     Alabama               29.9  Education  25+yrs & over
# 1  2017     State      Alaska               35.8  Education  25+yrs & over
# 2  2017     State     Arizona               33.9  Education  25+yrs & over
# 3  2017     State    Arkansas               29.2  Education  25+yrs & over
# 4  2017     State  California               29.3  Education  25+yrs & over
#
#          Description                               Notes
# 0  Percentage(Float)  Some college or associate's degree
# 1  Percentage(Float)  Some college or associate's degree
# 2  Percentage(Float)  Some college or associate's degree
# 3  Percentage(Float)  Some college or associate's degree
# 4  Percentage(Float)  Some college or associate's degree

# %%
# This function move footnotes to specific cells and remove Nan rows
def Update_FootNotes(_df):
    _df["Notes"] = "" 
    # Get all the 1st character in column, extract only digit & get the max    
    nlist = _df['Notes'].str[0].tolist()
    results = [int(n) for n in nlist if n.isdigit()]
    m = max(results)
    f = m
    # Loop thru the max and update footnote to specific row cell
    for i in range(m):
        n = (i+1)
        fn = f'-{f}'
        #         print(n)
        #         print(fn)
        footnote = _df.iloc[int(fn), 0].replace(f"{n} ", "")
#         print(footnote)
        _df.loc[_df.Notes.str.contains(str(n)), "Notes"] = f'Footnotes {n}: {footnote}'
        f-=1
    # -----------------------------------------------    
    # Drop all NaN rows
    _df = _df.dropna()
    # Remove digit from column
    pattern = '[0-9]'
    _df.Notes = [re.sub(pattern, '', row.Notes) for i, row in _df.iterrows()] 
        
    return _df

# %%
# Pass footnote to specific cells and clean data
# state_df = Update_FootNotes(state_df)
# Convert Column to Integer
# state_df[""] = state_df[""].astype(int)
# Some excel sheet has lowercase
# state_df.loc[state_df[""] == "", ""] = ""
# state_df.reset_index(drop=True,inplace=True)

# %%
final_state_df["Created_By"] = "Charleen"
final_state_df["Created_Date"] = pd.datetime.now().strftime("%m-%d-%Y %I:%M:%S")
final_state_df.head()
# Out:
#    Year Hierarchy      H_Name  Population_Number   Category    SubCategory  \
# 0  2017     State     Alabama               29.9  Education  25+yrs & over
# 1  2017     State      Alaska               35.8  Education  25+yrs & over
# 2  2017     State     Arizona               33.9  Education  25+yrs & over
# 3  2017     State    Arkansas               29.2  Education  25+yrs & over
# 4  2017     State  California               29.3  Education  25+yrs & over
#
#          Description                               Notes Created_By  \
# 0  Percentage(Float)  Some college or associate's degree   Charleen
# 1  Percentage(Float)  Some college or associate's degree   Charleen
# 2  Percentage(Float)  Some college or associate's degree   Charleen
# 3  Percentage(Float)  Some college or associate's degree   Charleen
# 4  Percentage(Float)  Some college or associate's degree   Charleen
#
#           Created_Date
# 0  05-05-2019 01:06:05
# 1  05-05-2019 01:06:05
# 2  05-05-2019 01:06:05
# 3  05-05-2019 01:06:05
# 4  05-05-2019 01:06:05

# %%
# # Create notes column and copy footnotes to Notes for selective row by locating the row cell with the footnote
# country_df["Notes"] = ""      
# country_df.loc[country_df.Crime_Type.str.contains('1'), "Notes"] = f'Footnotes: {country_df.iloc[-2, 0].replace("1 ", "")}'
# country_df.loc[country_df.Crime_Type.str.contains('2'), "Notes"] = f'Footnotes: {country_df.iloc[-1, 0].replace("2 ", "")}'
# # Drop all NaN rows
# country_df = country_df.dropna()
# # Remove digit from column
# pattern = '[0-9]'
# country_df.Crime_Type = [re.sub(pattern, '', row.Crime_Type) for i, row in country_df.iterrows()] 
final_state_df.count()
# Out:
# Year                 51
# Hierarchy            51
# H_Name               51
# Population_Number    51
# Category             51
# SubCategory          51
# Description          51
# Notes                51
# Created_By           51
# Created_Date         51
# dtype: int64

# %%
final_state_df.dtypes
# Out:
# Year                  object
# Hierarchy             object
# H_Name                object
# Population_Number    float64
# Category              object
# SubCategory           object
# Description           object
# Notes                 object
# Created_By            object
# Created_Date          object
# dtype: object

# %%
final_state_df['Year'] = final_state_df['Year'].astype(int)

# %%
final_state_df = final_state_df.astype({'Year': 'int64'})

# %%
final_state_df.dtypes
# Out:
# Year                   int64
# Hierarchy             object
# H_Name                object
# Population_Number    float64
# Category              object
# SubCategory           object
# Description           object
# Notes                 object
# Created_By            object
# Created_Date          object
# dtype: object

# %%
final_state_df['H_Name'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
len(final_state_df['H_Name'].unique())
# Out:
# 51

# %%
final_state_df.shape
# Out:
# (51, 10)

# %%
final_state_df.describe()
# Out:
#          Year  Population_Number
# count    51.0          51.000000
# mean   2017.0          29.915686
# std       0.0           4.059526
# min    2017.0          16.100000
# 25%    2017.0          27.500000
# 50%    2017.0          30.100000
# 75%    2017.0          32.750000
# max    2017.0          37.300000

# %%
# Set connection to database
client = MongoClient("mongodb+srv://admin:admin123@janie-test-vcn3t.mongodb.net/test?retryWrites=true")
db = client.consultant

# %%
records = final_state_df.to_dict('records')
[db.population.update_many({"Year": row["Year"], "Hierarchy": row["Hierarchy"], "H_Name": row["H_Name"], "Population_Number": row["Population_Number"], "Category": row["Category"], "SubCategory": row["SubCategory"], "Description": row["Description"], "Notes": row["Notes"], "Created_By": row["Created_By"], "Created_Date": row["Created_Date"]}, {'$set': row}, upsert=True) for row in records]
# Out:
# [<pymongo.results.UpdateResult at 0x1c56611cd88>,
#  <pymongo.results.UpdateResult at 0x1c566335888>,
#  <pymongo.results.UpdateResult at 0x1c566137ec8>,
#  <pymongo.results.UpdateResult at 0x1c5664a1fc8>,
#  <pymongo.results.UpdateResult at 0x1c566322a08>,
#  <pymongo.results.UpdateResult at 0x1c56646fe48>,
#  <pymongo.results.UpdateResult at 0x1c56646f848>,
#  <pymongo.results.UpdateResult at 0x1c56641ec48>,
#  <pymongo.results.UpdateResult at 0x1c5662aff88>,
#  <pymongo.results.UpdateResult at 0x1c56640c948>,
#  <pymongo.results.UpdateResult at 0x1c56647cc08>,
#  <pymongo.results.UpdateResult at 0x1c56641e4c8>,
#  <pymongo.results.UpdateResult at 0x1c5663f4f08>,
#  <pymongo.results.UpdateResult at 0x1c566420ac8>,
#  <pymongo.results.UpdateResult at 0x1c5663ed788>,
#  <pymongo.results.UpdateResult at 0x1c5664392c8>,
#  <pymongo.results.UpdateResult at 0x1c566452708>,
#  <pymongo.results.UpdateResult at 0x1c566409408>,
#  <pymongo.results.UpdateResult at 0x1c566411ac8>,
#  <pymongo.results.UpdateResult at 0x1c5662fc388>,
#  <pymongo.results.UpdateResult at 0x1c56633b988>,
#  <pymongo.results.UpdateResult at 0x1c5662e1988>,
#  <pymongo.results.UpdateResult at 0x1c5663fa308>,
#  <pymongo.results.UpdateResult at 0x1c566063788>,
#  <pymongo.results.UpdateResult at 0x1c566416748>,
#  <pymongo.results.UpdateResult at 0x1c5663f8c88>,
#  <pymongo.results.UpdateResult at 0x1c56643bfc8>,
#  <pymongo.results.UpdateResult at 0x1c566442088>,
#  <pymongo.results.UpdateResult at 0x1c5664456c8>,
#  <pymongo.results.UpdateResult at 0x1c56644a3c8>,
#  <pymongo.results.UpdateResult at 0x1c5664c5088>,
#  <pymongo.results.UpdateResult at 0x1c5664cbb48>,
#  <pymongo.results.UpdateResult at 0x1c5664cc248>,
#  <pymongo.results.UpdateResult at 0x1c5664d2108>,
#  <pymongo.results.UpdateResult at 0x1c5664d7d08>,
#  <pymongo.results.UpdateResult at 0x1c5664daec8>,
#  <pymongo.results.UpdateResult at 0x1c5664e3e08>,
#  <pymongo.results.UpdateResult at 0x1c5664e6f08>,
#  <pymongo.results.UpdateResult at 0x1c5664e9308>,
#  <pymongo.results.UpdateResult at 0x1c5664eff48>,
#  <pymongo.results.UpdateResult at 0x1c5664f2108>,
#  <pymongo.results.UpdateResult at 0x1c5664f8ac8>,
#  <pymongo.results.UpdateResult at 0x1c5664fe748>,
#  <pymongo.results.UpdateResult at 0x1c566502688>,
#  <pymongo.results.UpdateResult at 0x1c566505988>,
#  <pymongo.results.UpdateResult at 0x1c566508308>,
#  <pymongo.results.UpdateResult at 0x1c56650d548>,
#  <pymongo.results.UpdateResult at 0x1c566512648>,
#  <pymongo.results.UpdateResult at 0x1c566513148>,
#  <pymongo.results.UpdateResult at 0x1c5665161c8>,
#  <pymongo.results.UpdateResult at 0x1c56651c7c8>]

# %%
# Get data from mongo & convert back to dataframe
df = pd.DataFrame.from_records(db.population.find({}, {'_id': 0 }))
df
# Out:
#         Category Created_By         Created_Date        Description  \
# 0     Population   Charleen  05-05-2019 08:11:08            Integer
# 1     Population   Charleen  05-05-2019 08:11:08            Integer
# 2     Population   Charleen  05-05-2019 08:11:08            Integer
# 3     Population   Charleen  05-05-2019 08:11:08            Integer
# 4     Population   Charleen  05-05-2019 08:11:08            Integer
# 5     Population   Charleen  05-05-2019 08:11:08            Integer
# 6     Population   Charleen  05-05-2019 08:11:08            Integer
# 7     Population   Charleen  05-05-2019 08:11:08            Integer
# 8     Population   Charleen  05-05-2019 08:11:08            Integer
# 9     Population   Charleen  05-05-2019 08:11:08            Integer
# 10    Population   Charleen  05-05-2019 08:11:08            Integer
# 11    Population   Charleen  05-05-2019 08:11:08            Integer
# 12    Population   Charleen  05-05-2019 08:11:08            Integer
# 13    Population   Charleen  05-05-2019 08:11:08            Integer
# 14    Population   Charleen  05-05-2019 08:11:08            Integer
# 15    Population   Charleen  05-05-2019 08:11:08            Integer
# 16    Population   Charleen  05-05-2019 08:11:08            Integer
# 17    Population   Charleen  05-05-2019 08:11:08            Integer
# 18    Population   Charleen  05-05-2019 08:11:08            Integer
# 19    Population   Charleen  05-05-2019 08:11:08            Integer
# 20    Population   Charleen  05-05-2019 08:11:08            Integer
# 21    Population   Charleen  05-05-2019 08:11:08            Integer
# 22    Population   Charleen  05-05-2019 08:11:08            Integer
# 23    Population   Charleen  05-05-2019 08:11:08            Integer
# 24    Population   Charleen  05-05-2019 08:11:08            Integer
# 25    Population   Charleen  05-05-2019 08:11:08            Integer
# 26    Population   Charleen  05-05-2019 08:11:08            Integer
# 27    Population   Charleen  05-05-2019 08:11:08            Integer
# 28    Population   Charleen  05-05-2019 08:11:08            Integer
# 29    Population   Charleen  05-05-2019 08:11:08            Integer
# ...          ...        ...                  ...                ...
# 3183   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3184   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3185   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3186   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3187   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3188   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3189   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3190   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3191   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3192   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3193   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3194   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3195   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3196   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3197   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3198   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3199   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3200   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3201   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3202   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3203   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3204   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3205   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3206   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3207   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3208   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3209   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3210   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3211   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
# 3212   Education   Charleen  05-05-2019 01:06:05  Percentage(Float)
#
#                     H_Name Hierarchy                               Notes  \
# 0                  Alabama     State
# 1                   Alaska     State
# 2                  Arizona     State
# 3                 Arkansas     State
# 4               California     State
# 5                 Colorado     State
# 6              Connecticut     State
# 7                 Delaware     State
# 8     District of Columbia     State
# 9                  Florida     State
# 10                 Georgia     State
# 11                  Hawaii     State
# 12                   Idaho     State
# 13                Illinois     State
# 14                 Indiana     State
# 15                    Iowa     State
# 16                  Kansas     State
# 17                Kentucky     State
# 18               Louisiana     State
# 19                   Maine     State
# 20                Maryland     State
# 21           Massachusetts     State
# 22                Michigan     State
# 23               Minnesota     State
# 24             Mississippi     State
# 25                Missouri     State
# 26                 Montana     State
# 27                Nebraska     State
# 28                  Nevada     State
# 29           New Hampshire     State
# ...                    ...       ...                                 ...
# 3183         Massachusetts     State  Some college or associate's degree
# 3184              Michigan     State  Some college or associate's degree
# 3185             Minnesota     State  Some college or associate's degree
# 3186           Mississippi     State  Some college or associate's degree
# 3187              Missouri     State  Some college or associate's degree
# 3188               Montana     State  Some college or associate's degree
# 3189              Nebraska     State  Some college or associate's degree
# 3190                Nevada     State  Some college or associate's degree
# 3191         New Hampshire     State  Some college or associate's degree
# 3192            New Jersey     State  Some college or associate's degree
# 3193            New Mexico     State  Some college or associate's degree
# 3194              New York     State  Some college or associate's degree
# 3195        North Carolina     State  Some college or associate's degree
# 3196          North Dakota     State  Some college or associate's degree
# 3197                  Ohio     State  Some college or associate's degree
# 3198              Oklahoma     State  Some college or associate's degree
# 3199                Oregon     State  Some college or associate's degree
# 3200          Pennsylvania     State  Some college or associate's degree
# 3201          Rhode Island     State  Some college or associate's degree
# 3202        South Carolina     State  Some college or associate's degree
# 3203          South Dakota     State  Some college or associate's degree
# 3204             Tennessee     State  Some college or associate's degree
# 3205                 Texas     State  Some college or associate's degree
# 3206                  Utah     State  Some college or associate's degree
# 3207               Vermont     State  Some college or associate's degree
# 3208              Virginia     State  Some college or associate's degree
# 3209            Washington     State  Some college or associate's degree
# 3210         West Virginia     State  Some college or associate's degree
# 3211             Wisconsin     State  Some college or associate's degree
# 3212               Wyoming     State  Some college or associate's degree
#
#       Population_Number    SubCategory  Year
# 0             4633360.0          Total  2009
# 1              683142.0          Total  2009
# 2             6324865.0          Total  2009
# 3             2838143.0          Total  2009
# 4            36308527.0          Total  2009
# 5             4843211.0          Total  2009
# 6             3494487.0          Total  2009
# 7              863832.0          Total  2009
# 8              588433.0          Total  2009
# 9            18222420.0          Total  2009
# 10            9497667.0          Total  2009
# 11            1280241.0          Total  2009
# 12            1492573.0          Total  2009
# 13           12785043.0          Total  2009
# 14            6342469.0          Total  2009
# 15            2978880.0          Total  2009
# 16            2777835.0          Total  2009
# 17            4252000.0          Total  2009
# 18            4411546.0          Total  2009
# 19            1316380.0          Total  2009
# 20            5637418.0          Total  2009
# 21            6511176.0          Total  2009
# 22           10039208.0          Total  2009
# 23            5188581.0          Total  2009
# 24            2922240.0          Total  2009
# 25            5904382.0          Total  2009
# 26             956257.0          Total  2009
# 27            1772124.0          Total  2009
# 28            2545763.0          Total  2009
# 29            1315419.0          Total  2009
# ...                 ...            ...   ...
# 3183               23.5  25+yrs & over  2017
# 3184               32.9  25+yrs & over  2017
# 3185               32.6  25+yrs & over  2017
# 3186               31.7  25+yrs & over  2017
# 3187               30.1  25+yrs & over  2017
# 3188               32.9  25+yrs & over  2017
# 3189               33.6  25+yrs & over  2017
# 3190               33.9  25+yrs & over  2017
# 3191               28.8  25+yrs & over  2017
# 3192               23.1  25+yrs & over  2017
# 3193               31.7  25+yrs & over  2017
# 3194               24.5  25+yrs & over  2017
# 3195               30.9  25+yrs & over  2017
# 3196               36.3  25+yrs & over  2017
# 3197               29.0  25+yrs & over  2017
# 3198               31.2  25+yrs & over  2017
# 3199               34.5  25+yrs & over  2017
# 3200               24.2  25+yrs & over  2017
# 3201               26.5  25+yrs & over  2017
# 3202               30.1  25+yrs & over  2017
# 3203               33.1  25+yrs & over  2017
# 3204               27.8  25+yrs & over  2017
# 3205               29.0  25+yrs & over  2017
# 3206               36.4  25+yrs & over  2017
# 3207               25.9  25+yrs & over  2017
# 3208               27.2  25+yrs & over  2017
# 3209               33.9  25+yrs & over  2017
# 3210               25.5  25+yrs & over  2017
# 3211               31.4  25+yrs & over  2017
# 3212               37.3  25+yrs & over  2017
#
# [3213 rows x 10 columns]

# %%
# db.population.drop()
