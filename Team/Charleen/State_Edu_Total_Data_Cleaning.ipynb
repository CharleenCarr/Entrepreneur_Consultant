# %%
# Dependencies
import os
import sys
import re 
import pandas as pd
import numpy as np
from pymongo import MongoClient
import shutil
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Set directory file paths
filepath = os.path.join(".", "Resources/State/Demographic", "ACS_17_5YR_S0102_with_ann.csv")

# %%
total_state_df = pd.read_csv(filepath, skiprows=[0])
# Split the extension from the path and normalise it to lowercase.
# ext = os.path.splitext(filepath)[-1].lower()
# excel = os.path.splitext(filepath)[0].lower()

# state_df["Year"] = "2009"
# state_df["Year"] = int(excel.split("_")[-1])
total_state_df.head()
# Out:
#             Id  Id2   Geography  Total; Estimate; Total population  \
# 0  0400000US01    1     Alabama                            4850771
# 1  0400000US02    2      Alaska                             738565
# 2  0400000US04    4     Arizona                            6809946
# 3  0400000US05    5    Arkansas                            2977944
# 4  0400000US06    6  California                           38982847
#
#   Total; Margin of Error; Total population  \
# 0                                    *****
# 1                                    *****
# 2                                    *****
# 3                                    *****
# 4                                    *****
#
#    60 years and over; Estimate; Total population  \
# 0                                        1065625
# 1                                         117047
# 2                                        1502688
# 3                                         655552
# 4                                        7292299
#
#    60 years and over; Margin of Error; Total population  \
# 0                                               3368
# 1                                               1030
# 2                                               3385
# 3                                               2090
# 4                                               6791
#
#    Total; Estimate; SEX AND AGE - Male  \
# 0                                 48.5
# 1                                 52.3
# 2                                 49.7
# 3                                 49.1
# 4                                 49.7
#
#    Total; Margin of Error; SEX AND AGE - Male  \
# 0                                         0.1
# 1                                         0.1
# 2                                         0.1
# 3                                         0.1
# 4                                         0.1
#
#    60 years and over; Estimate; SEX AND AGE - Male  \
# 0                                             44.4
# 1                                             50.8
# 2                                             46.3
# 3                                             45.3
# 4                                             45.4
#
#                                        ...                                       \
# 0                                      ...
# 1                                      ...
# 2                                      ...
# 3                                      ...
# 4                                      ...
#
#    60 years and over; Estimate; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Less than 30 percent  \
# 0                                               55.2
# 1                                               56.5
# 2                                               48.3
# 3                                               56.6
# 4                                               40.0
#
#    60 years and over; Margin of Error; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Less than 30 percent  \
# 0                                                1.0
# 1                                                2.6
# 2                                                0.8
# 3                                                1.3
# 4                                                0.3
#
#    Total; Estimate; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                               42.6
# 1                                               41.6
# 2                                               45.2
# 3                                               40.7
# 4                                               53.1
#
#    Total; Margin of Error; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                                0.5
# 1                                                1.1
# 2                                                0.4
# 3                                                0.6
# 4                                                0.1
#
#    60 years and over; Estimate; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                               44.8
# 1                                               43.5
# 2                                               51.7
# 3                                               43.4
# 4                                               60.0
#
#    60 years and over; Margin of Error; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                                1.0
# 1                                                2.6
# 2                                                0.8
# 3                                                1.3
# 4                                                0.3
#
#    Total; Estimate; GROSS RENT - Median gross rent (dollars)  \
# 0                                                747
# 1                                               1200
# 2                                                972
# 3                                                709
# 4                                               1358
#
#    Total; Margin of Error; GROSS RENT - Median gross rent (dollars)  \
# 0                                                  3
# 1                                                 13
# 2                                                  4
# 3                                                  5
# 4                                                  3
#
#    60 years and over; Estimate; GROSS RENT - Median gross rent (dollars)  \
# 0                                                623
# 1                                                902
# 2                                                880
# 3                                                613
# 4                                               1109
#
#    60 years and over; Margin of Error; GROSS RENT - Median gross rent (dollars)
# 0                                                  8
# 1                                                 29
# 2                                                  8
# 3                                                  9
# 4                                                  4
#
# [5 rows x 427 columns]

# %%
edu_state_cols_df = total_state_df.filter(regex="Total; Estimate; EDUCATIONAL ATTAINMENT")
edu_state_df = total_state_df.filter(regex="Geography")

edu_state_df.head()
edu_state_cols_df.head()
# Out:
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over  \
# 0                                            3276637
# 1                                             475442
# 2                                            4516175
# 3                                            1985770
# 4                                           25950818
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than high school graduate  \
# 0                                               14.7
# 1                                                7.6
# 2                                               13.5
# 3                                               14.4
# 4                                               17.5
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate, GED, or alternative  \
# 0                                               30.9
# 1                                               27.6
# 2                                               24.2
# 3                                               34.3
# 4                                               20.6
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college or associate's degree  \
# 0                                               29.9
# 1                                               35.8
# 2                                               33.9
# 3                                               29.2
# 4                                               29.3
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher
# 0                                               24.5
# 1                                               29.0
# 2                                               28.4
# 3                                               22.0
# 4                                               32.6

# %%
total_edu_state_df = pd.concat([edu_state_df, edu_state_cols_df], axis=1)

total_edu_state_df.head()
# Out:
#     Geography  \
# 0     Alabama
# 1      Alaska
# 2     Arizona
# 3    Arkansas
# 4  California
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over  \
# 0                                            3276637
# 1                                             475442
# 2                                            4516175
# 3                                            1985770
# 4                                           25950818
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than high school graduate  \
# 0                                               14.7
# 1                                                7.6
# 2                                               13.5
# 3                                               14.4
# 4                                               17.5
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate, GED, or alternative  \
# 0                                               30.9
# 1                                               27.6
# 2                                               24.2
# 3                                               34.3
# 4                                               20.6
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college or associate's degree  \
# 0                                               29.9
# 1                                               35.8
# 2                                               33.9
# 3                                               29.2
# 4                                               29.3
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher
# 0                                               24.5
# 1                                               29.0
# 2                                               28.4
# 3                                               22.0
# 4                                               32.6

# %%
total_edu_state_df["Year"] = "2017"
# state_df["Year"] = int(excel.split("_")[-1])
total_edu_state_df.head()
# Out:
#     Geography  \
# 0     Alabama
# 1      Alaska
# 2     Arizona
# 3    Arkansas
# 4  California
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over  \
# 0                                            3276637
# 1                                             475442
# 2                                            4516175
# 3                                            1985770
# 4                                           25950818
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than high school graduate  \
# 0                                               14.7
# 1                                                7.6
# 2                                               13.5
# 3                                               14.4
# 4                                               17.5
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate, GED, or alternative  \
# 0                                               30.9
# 1                                               27.6
# 2                                               24.2
# 3                                               34.3
# 4                                               20.6
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college or associate's degree  \
# 0                                               29.9
# 1                                               35.8
# 2                                               33.9
# 3                                               29.2
# 4                                               29.3
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher  \
# 0                                               24.5
# 1                                               29.0
# 2                                               28.4
# 3                                               22.0
# 4                                               32.6
#
#    Year
# 0  2017
# 1  2017
# 2  2017
# 3  2017
# 4  2017

# %%
# Pass sheet title to description & country to hierachy columns for each row
total_edu_state_df["Hierarchy"] = "State"
# state_df["H_Name"] = list(state_df)[2]
# state_df["Population_Number"] = list(state_df)[3]
total_edu_state_df["Category"] = "Education"
total_edu_state_df["SubCategory"] = "Total"
total_edu_state_df["Description"] = "Integer"
total_edu_state_df["Notes"] = "25+yrs & over"

# Rename 1st two columns
mapping = {total_edu_state_df.columns[0]: 'H_Name', total_edu_state_df.columns[1]: 'Population_Number'}
state_df = total_edu_state_df.rename(columns=mapping)

state_df.head()
# Out:
#        H_Name  Population_Number  \
# 0     Alabama            3276637
# 1      Alaska             475442
# 2     Arizona            4516175
# 3    Arkansas            1985770
# 4  California           25950818
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than high school graduate  \
# 0                                               14.7
# 1                                                7.6
# 2                                               13.5
# 3                                               14.4
# 4                                               17.5
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate, GED, or alternative  \
# 0                                               30.9
# 1                                               27.6
# 2                                               24.2
# 3                                               34.3
# 4                                               20.6
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college or associate's degree  \
# 0                                               29.9
# 1                                               35.8
# 2                                               33.9
# 3                                               29.2
# 4                                               29.3
#
#    Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher  \
# 0                                               24.5
# 1                                               29.0
# 2                                               28.4
# 3                                               22.0
# 4                                               32.6
#
#    Year Hierarchy   Category SubCategory Description          Notes
# 0  2017     State  Education       Total     Integer  25+yrs & over
# 1  2017     State  Education       Total     Integer  25+yrs & over
# 2  2017     State  Education       Total     Integer  25+yrs & over
# 3  2017     State  Education       Total     Integer  25+yrs & over
# 4  2017     State  Education       Total     Integer  25+yrs & over

# %%
state_df.columns
# Out:
# Index(['H_Name', 'Population_Number',
#        'Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Less than high school graduate',
#        'Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate, GED, or alternative',
#        'Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Some college or associate's degree',
#        'Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher',
#        'Year', 'Hierarchy', 'Category', 'SubCategory', 'Description', 'Notes'],
#       dtype='object')

# %%
final_state_df = state_df[['Year', 'Hierarchy', 'H_Name', 'Population_Number', 'Category', 'SubCategory', 'Description', 'Notes']]
final_state_df.head()
# Out:
#    Year Hierarchy      H_Name  Population_Number   Category SubCategory  \
# 0  2017     State     Alabama            3276637  Education       Total
# 1  2017     State      Alaska             475442  Education       Total
# 2  2017     State     Arizona            4516175  Education       Total
# 3  2017     State    Arkansas            1985770  Education       Total
# 4  2017     State  California           25950818  Education       Total
#
#   Description          Notes
# 0     Integer  25+yrs & over
# 1     Integer  25+yrs & over
# 2     Integer  25+yrs & over
# 3     Integer  25+yrs & over
# 4     Integer  25+yrs & over

# %%
# This function move footnotes to specific cells and remove Nan rows
def Update_FootNotes(_df):
    _df["Notes"] = "" 
    # Get all the 1st character in column, extract only digit & get the max    
    nlist = _df['Notes'].str[0].tolist()
    results = [int(n) for n in nlist if n.isdigit()]
    m = max(results)
    f = m
    # Loop thru the max and update footnote to specific row cell
    for i in range(m):
        n = (i+1)
        fn = f'-{f}'
        #         print(n)
        #         print(fn)
        footnote = _df.iloc[int(fn), 0].replace(f"{n} ", "")
#         print(footnote)
        _df.loc[_df.Notes.str.contains(str(n)), "Notes"] = f'Footnotes {n}: {footnote}'
        f-=1
    # -----------------------------------------------    
    # Drop all NaN rows
    _df = _df.dropna()
    # Remove digit from column
    pattern = '[0-9]'
    _df.Notes = [re.sub(pattern, '', row.Notes) for i, row in _df.iterrows()] 
        
    return _df

# %%
# Pass footnote to specific cells and clean data
# state_df = Update_FootNotes(state_df)
# Convert Column to Integer
# state_df[""] = state_df[""].astype(int)
# Some excel sheet has lowercase
# state_df.loc[state_df[""] == "", ""] = ""
# state_df.reset_index(drop=True,inplace=True)

# %%
final_state_df["Created_By"] = "Charleen"
final_state_df["Created_Date"] = pd.datetime.now().strftime("%m-%d-%Y %I:%M:%S")
final_state_df.head()
# Out:
#    Year Hierarchy      H_Name  Population_Number   Category SubCategory  \
# 0  2017     State     Alabama            3276637  Education       Total
# 1  2017     State      Alaska             475442  Education       Total
# 2  2017     State     Arizona            4516175  Education       Total
# 3  2017     State    Arkansas            1985770  Education       Total
# 4  2017     State  California           25950818  Education       Total
#
#   Description          Notes Created_By         Created_Date
# 0     Integer  25+yrs & over   Charleen  05-05-2019 10:42:22
# 1     Integer  25+yrs & over   Charleen  05-05-2019 10:42:22
# 2     Integer  25+yrs & over   Charleen  05-05-2019 10:42:22
# 3     Integer  25+yrs & over   Charleen  05-05-2019 10:42:22
# 4     Integer  25+yrs & over   Charleen  05-05-2019 10:42:22

# %%
# # Create notes column and copy footnotes to Notes for selective row by locating the row cell with the footnote
# country_df["Notes"] = ""      
# country_df.loc[country_df.Crime_Type.str.contains('1'), "Notes"] = f'Footnotes: {country_df.iloc[-2, 0].replace("1 ", "")}'
# country_df.loc[country_df.Crime_Type.str.contains('2'), "Notes"] = f'Footnotes: {country_df.iloc[-1, 0].replace("2 ", "")}'
# # Drop all NaN rows
# country_df = country_df.dropna()
# # Remove digit from column
# pattern = '[0-9]'
# country_df.Crime_Type = [re.sub(pattern, '', row.Crime_Type) for i, row in country_df.iterrows()] 
final_state_df.count()
# Out:
# Year                 51
# Hierarchy            51
# H_Name               51
# Population_Number    51
# Category             51
# SubCategory          51
# Description          51
# Notes                51
# Created_By           51
# Created_Date         51
# dtype: int64

# %%
final_state_df.dtypes
# Out:
# Year                 object
# Hierarchy            object
# H_Name               object
# Population_Number     int64
# Category             object
# SubCategory          object
# Description          object
# Notes                object
# Created_By           object
# Created_Date         object
# dtype: object

# %%
final_state_df['Year'] = final_state_df['Year'].astype(int)

# %%
final_state_df = final_state_df.astype({'Year': 'int64'})

# %%
final_state_df.dtypes
# Out:
# Year                  int64
# Hierarchy            object
# H_Name               object
# Population_Number     int64
# Category             object
# SubCategory          object
# Description          object
# Notes                object
# Created_By           object
# Created_Date         object
# dtype: object

# %%
final_state_df['H_Name'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
len(final_state_df['H_Name'].unique())
# Out:
# 51

# %%
final_state_df.shape
# Out:
# (51, 10)

# %%
final_state_df.describe()
# Out:
#          Year  Population_Number
# count    51.0       5.100000e+01
# mean   2017.0       4.240620e+06
# std       0.0       4.804459e+06
# min    2017.0       3.886170e+05
# 25%    2017.0       1.149578e+06
# 50%    2017.0       2.986199e+06
# 75%    2017.0       4.801296e+06
# max    2017.0       2.595082e+07

# %%
# Set connection to database
client = MongoClient("mongodb+srv://admin:admin123@janie-test-vcn3t.mongodb.net/test?retryWrites=true")
db = client.consultant

# %%
records = final_state_df.to_dict('records')
[db.population.update_many({"Year": row["Year"], "Hierarchy": row["Hierarchy"], "H_Name": row["H_Name"], "Population_Number": row["Population_Number"], "Category": row["Category"], "SubCategory": row["SubCategory"], "Description": row["Description"], "Notes": row["Notes"], "Created_By": row["Created_By"], "Created_Date": row["Created_Date"]}, {'$set': row}, upsert=True) for row in records]
# Out:
# [<pymongo.results.UpdateResult at 0x2c9c950e0c8>,
#  <pymongo.results.UpdateResult at 0x2c9c95cb288>,
#  <pymongo.results.UpdateResult at 0x2c9c9294888>,
#  <pymongo.results.UpdateResult at 0x2c9c93565c8>,
#  <pymongo.results.UpdateResult at 0x2c9c95c4e08>,
#  <pymongo.results.UpdateResult at 0x2c9c95d1988>,
#  <pymongo.results.UpdateResult at 0x2c9c95e4b48>,
#  <pymongo.results.UpdateResult at 0x2c9c95e6fc8>,
#  <pymongo.results.UpdateResult at 0x2c9c95e65c8>,
#  <pymongo.results.UpdateResult at 0x2c9c95c7648>,
#  <pymongo.results.UpdateResult at 0x2c9c95e6908>,
#  <pymongo.results.UpdateResult at 0x2c9c95e9b48>,
#  <pymongo.results.UpdateResult at 0x2c9c95abc08>,
#  <pymongo.results.UpdateResult at 0x2c9c9844a08>,
#  <pymongo.results.UpdateResult at 0x2c9c95aeb08>,
#  <pymongo.results.UpdateResult at 0x2c9c95b1d48>,
#  <pymongo.results.UpdateResult at 0x2c9c95bdc08>,
#  <pymongo.results.UpdateResult at 0x2c9c95c1dc8>,
#  <pymongo.results.UpdateResult at 0x2c9c95c1f08>,
#  <pymongo.results.UpdateResult at 0x2c9c95a8fc8>,
#  <pymongo.results.UpdateResult at 0x2c9c95d3888>,
#  <pymongo.results.UpdateResult at 0x2c9c95d6448>,
#  <pymongo.results.UpdateResult at 0x2c9c95da1c8>,
#  <pymongo.results.UpdateResult at 0x2c9c95dca48>,
#  <pymongo.results.UpdateResult at 0x2c9c9675048>,
#  <pymongo.results.UpdateResult at 0x2c9c9675ec8>,
#  <pymongo.results.UpdateResult at 0x2c9c9678848>,
#  <pymongo.results.UpdateResult at 0x2c9c961ccc8>,
#  <pymongo.results.UpdateResult at 0x2c9c967c588>,
#  <pymongo.results.UpdateResult at 0x2c9c967c188>,
#  <pymongo.results.UpdateResult at 0x2c9c967d808>,
#  <pymongo.results.UpdateResult at 0x2c9c9681388>,
#  <pymongo.results.UpdateResult at 0x2c9c9685708>,
#  <pymongo.results.UpdateResult at 0x2c9c9685408>,
#  <pymongo.results.UpdateResult at 0x2c9c961bec8>,
#  <pymongo.results.UpdateResult at 0x2c9c9687908>,
#  <pymongo.results.UpdateResult at 0x2c9c968a288>,
#  <pymongo.results.UpdateResult at 0x2c9c968ad88>,
#  <pymongo.results.UpdateResult at 0x2c9c968e088>,
#  <pymongo.results.UpdateResult at 0x2c9c968ec48>,
#  <pymongo.results.UpdateResult at 0x2c9c9693848>,
#  <pymongo.results.UpdateResult at 0x2c9c9691388>,
#  <pymongo.results.UpdateResult at 0x2c9c9691e88>,
#  <pymongo.results.UpdateResult at 0x2c9c9697688>,
#  <pymongo.results.UpdateResult at 0x2c9c96976c8>,
#  <pymongo.results.UpdateResult at 0x2c9c969ad88>,
#  <pymongo.results.UpdateResult at 0x2c9c969a7c8>,
#  <pymongo.results.UpdateResult at 0x2c9c969ee08>,
#  <pymongo.results.UpdateResult at 0x2c9c96a0348>,
#  <pymongo.results.UpdateResult at 0x2c9c96a0dc8>,
#  <pymongo.results.UpdateResult at 0x2c9c96a3308>]

# %%
# Get data from mongo & convert back to dataframe
df = pd.DataFrame.from_records(db.population.find({}, {'_id': 0 }))
df
# Out:
#         Category Created_By         Created_Date Description  \
# 0     Population   Charleen  05-05-2019 08:11:08     Integer
# 1     Population   Charleen  05-05-2019 08:11:08     Integer
# 2     Population   Charleen  05-05-2019 08:11:08     Integer
# 3     Population   Charleen  05-05-2019 08:11:08     Integer
# 4     Population   Charleen  05-05-2019 08:11:08     Integer
# 5     Population   Charleen  05-05-2019 08:11:08     Integer
# 6     Population   Charleen  05-05-2019 08:11:08     Integer
# 7     Population   Charleen  05-05-2019 08:11:08     Integer
# 8     Population   Charleen  05-05-2019 08:11:08     Integer
# 9     Population   Charleen  05-05-2019 08:11:08     Integer
# 10    Population   Charleen  05-05-2019 08:11:08     Integer
# 11    Population   Charleen  05-05-2019 08:11:08     Integer
# 12    Population   Charleen  05-05-2019 08:11:08     Integer
# 13    Population   Charleen  05-05-2019 08:11:08     Integer
# 14    Population   Charleen  05-05-2019 08:11:08     Integer
# 15    Population   Charleen  05-05-2019 08:11:08     Integer
# 16    Population   Charleen  05-05-2019 08:11:08     Integer
# 17    Population   Charleen  05-05-2019 08:11:08     Integer
# 18    Population   Charleen  05-05-2019 08:11:08     Integer
# 19    Population   Charleen  05-05-2019 08:11:08     Integer
# 20    Population   Charleen  05-05-2019 08:11:08     Integer
# 21    Population   Charleen  05-05-2019 08:11:08     Integer
# 22    Population   Charleen  05-05-2019 08:11:08     Integer
# 23    Population   Charleen  05-05-2019 08:11:08     Integer
# 24    Population   Charleen  05-05-2019 08:11:08     Integer
# 25    Population   Charleen  05-05-2019 08:11:08     Integer
