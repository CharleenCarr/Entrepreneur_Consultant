# %%
# Dependencies
import os
import sys
import re 
import pandas as pd
import numpy as np
from pymongo import MongoClient
import shutil
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Set directory file paths
filepath = os.path.join(".", "Resources/State/Demographic", "ACS_13_5YR_S0102_with_ann.csv")

# %%
total_state_df = pd.read_csv(filepath, skiprows=[0])
# Split the extension from the path and normalise it to lowercase.
# ext = os.path.splitext(filepath)[-1].lower()
# excel = os.path.splitext(filepath)[0].lower()

# state_df["Year"] = "2009"
# state_df["Year"] = int(excel.split("_")[-1])
total_state_df.head()
# Out:
#             Id  Id2   Geography  Total; Estimate; Total population  \
# 0  0400000US01    1     Alabama                            4799277
# 1  0400000US02    2      Alaska                             720316
# 2  0400000US04    4     Arizona                            6479703
# 3  0400000US05    5    Arkansas                            2933369
# 4  0400000US06    6  California                           37659181
#
#   Total; Margin of Error; Total population  \
# 0                                    *****
# 1                                    *****
# 2                                    *****
# 3                                    *****
# 4                                    *****
#
#    60 years and over; Estimate; Total population  \
# 0                                         966454
# 1                                          96430
# 2                                        1294109
# 3                                         601493
# 4                                        6360929
#
#    60 years and over; Margin of Error; Total population  \
# 0                                               2674
# 1                                                985
# 2                                               3052
# 3                                               2218
# 4                                               7359
#
#    Total; Estimate; SEX AND AGE - Male  \
# 0                                 48.5
# 1                                 52.2
# 2                                 49.7
# 3                                 49.1
# 4                                 49.7
#
#    Total; Margin of Error; SEX AND AGE - Male  \
# 0                                         0.1
# 1                                         0.1
# 2                                         0.1
# 3                                         0.1
# 4                                         0.1
#
#    60 years and over; Estimate; SEX AND AGE - Male  \
# 0                                             44.1
# 1                                             50.3
# 2                                             46.1
# 3                                             44.9
# 4                                             45.0
#
#                                        ...                                       \
# 0                                      ...
# 1                                      ...
# 2                                      ...
# 3                                      ...
# 4                                      ...
#
#    60 years and over; Estimate; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Less than 30 percent  \
# 0                                               56.0
# 1                                               52.6
# 2                                               46.1
# 3                                               58.1
# 4                                               40.2
#
#    60 years and over; Margin of Error; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Less than 30 percent  \
# 0                                                1.0
# 1                                                2.7
# 2                                                0.9
# 3                                                1.3
# 4                                                0.3
#
#    Total; Estimate; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                               44.8
# 1                                               40.6
# 2                                               47.5
# 3                                               43.0
# 4                                               54.1
#
#    Total; Margin of Error; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                                0.6
# 1                                                0.9
# 2                                                0.4
# 3                                                0.6
# 4                                                0.2
#
#    60 years and over; Estimate; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                               44.0
# 1                                               47.4
# 2                                               53.9
# 3                                               41.9
# 4                                               59.8
#
#    60 years and over; Margin of Error; Renter-occupied housing units - GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - 30 percent or more  \
# 0                                                1.0
# 1                                                2.7
# 2                                                0.9
# 3                                                1.3
# 4                                                0.3
#
#    Total; Estimate; GROSS RENT - Median gross rent (dollars)  \
# 0                                                705
# 1                                               1098
# 2                                                896
# 3                                                661
# 4                                               1224
#
#    Total; Margin of Error; GROSS RENT - Median gross rent (dollars)  \
# 0                                                  3
# 1                                                 13
# 2                                                  4
# 3                                                  4
# 4                                                  2
#
#    60 years and over; Estimate; GROSS RENT - Median gross rent (dollars)  \
# 0                                                569
# 1                                                846
# 2                                                836
# 3                                                565
# 4                                                994
#
#    60 years and over; Margin of Error; GROSS RENT - Median gross rent (dollars)
# 0                                                  9
# 1                                                 23
# 2                                                  8
# 3                                                  9
# 4                                                  4
#
# [5 rows x 427 columns]

# %%
demo_state_cols_df = total_state_df.filter(regex="RACE AND HISPANIC OR LATINO ORIGIN")
demo_state_df = total_state_df.filter(regex="Geography")

demo_state_df.head()
demo_state_cols_df.head()
# Out:
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0                                               98.5
# 1                                               92.1
# 2                                               97.0
# 3                                               98.0
# 4                                               95.7
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0                                                0.1
# 1                                                0.2
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0                                               99.2
# 1                                               97.6
# 2                                               99.0
# 3                                               98.9
# 4                                               98.1
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0                                                0.1
# 1                                                0.3
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                               69.3
# 1                                               66.9
# 2                                               79.2
# 3                                               78.3
# 4                                               62.3
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                                0.1
# 1                                                0.1
# 2                                                0.2
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                               78.9
# 1                                               76.8
# 2                                               90.1
# 3                                               87.6
# 4                                               72.6
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                                0.1
# 1                                                0.4
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American  \
# 0                                               26.3
# 1                                                3.5
# 2                                                4.2
# 3                                               15.5
# 4                                                6.0
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American  \
# 0                                                0.1
# 1                                                0.1
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#                                               ...                                              \
# 0                                             ...
# 1                                             ...
# 2                                             ...
# 3                                             ...
# 4                                             ...
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander  \
# 0                                                0.0
# 1                                                0.5
# 2                                                0.1
# 3                                                0.0
# 4                                                0.3
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander  \
# 0                                                0.1
# 1                                                0.1
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                1.2
# 1                                                1.2
# 2                                                6.2
# 3                                                2.2
# 4                                               12.9
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                0.1
# 1                                                0.1
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                0.2
# 1                                                0.6
# 2                                                2.4
# 3                                                0.4
# 4                                                5.4
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                0.1
# 1                                                0.2
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                1.5
# 1                                                7.9
# 2                                                3.0
# 3                                                2.0
# 4                                                4.3
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                0.1
# 1                                                0.2
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                0.8
# 1                                                2.4
# 2                                                1.0
# 3                                                1.1
# 4                                                1.9
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races
# 0                                                0.1
# 1                                                0.3
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
# [5 rows x 32 columns]

# %%
total_demo_state_df = pd.concat([demo_state_df, demo_state_cols_df], axis=1)

total_demo_state_df.head()
# Out:
#     Geography  Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0     Alabama                                               98.5
# 1      Alaska                                               92.1
# 2     Arizona                                               97.0
# 3    Arkansas                                               98.0
# 4  California                                               95.7
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0                                                0.1
# 1                                                0.2
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0                                               99.2
# 1                                               97.6
# 2                                               99.0
# 3                                               98.9
# 4                                               98.1
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0                                                0.1
# 1                                                0.3
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                               69.3
# 1                                               66.9
# 2                                               79.2
# 3                                               78.3
# 4                                               62.3
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                                0.1
# 1                                                0.1
# 2                                                0.2
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                               78.9
# 1                                               76.8
# 2                                               90.1
# 3                                               87.6
# 4                                               72.6
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                                0.1
# 1                                                0.4
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American  \
# 0                                               26.3
# 1                                                3.5
# 2                                                4.2
# 3                                               15.5
# 4                                                6.0
#
#                                               ...                                              \
# 0                                             ...
# 1                                             ...
# 2                                             ...
# 3                                             ...
# 4                                             ...
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander  \
# 0                                                0.0
# 1                                                0.5
# 2                                                0.1
# 3                                                0.0
# 4                                                0.3
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander  \
# 0                                                0.1
# 1                                                0.1
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                1.2
# 1                                                1.2
# 2                                                6.2
# 3                                                2.2
# 4                                               12.9
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                0.1
# 1                                                0.1
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                0.2
# 1                                                0.6
# 2                                                2.4
# 3                                                0.4
# 4                                                5.4
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                0.1
# 1                                                0.2
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                1.5
# 1                                                7.9
# 2                                                3.0
# 3                                                2.0
# 4                                                4.3
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                0.1
# 1                                                0.2
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                0.8
# 1                                                2.4
# 2                                                1.0
# 3                                                1.1
# 4                                                1.9
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races
# 0                                                0.1
# 1                                                0.3
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
# [5 rows x 33 columns]

# %%
total_demo_state_df["Year"] = "2013"
# state_df["Year"] = int(excel.split("_")[-1])
total_demo_state_df.head()
# Out:
#     Geography  Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0     Alabama                                               98.5
# 1      Alaska                                               92.1
# 2     Arizona                                               97.0
# 3    Arkansas                                               98.0
# 4  California                                               95.7
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0                                                0.1
# 1                                                0.2
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0                                               99.2
# 1                                               97.6
# 2                                               99.0
# 3                                               98.9
# 4                                               98.1
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0                                                0.1
# 1                                                0.3
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                               69.3
# 1                                               66.9
# 2                                               79.2
# 3                                               78.3
# 4                                               62.3
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                                0.1
# 1                                                0.1
# 2                                                0.2
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                               78.9
# 1                                               76.8
# 2                                               90.1
# 3                                               87.6
# 4                                               72.6
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                                0.1
# 1                                                0.4
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American  \
# 0                                               26.3
# 1                                                3.5
# 2                                                4.2
# 3                                               15.5
# 4                                                6.0
#
#    ...   \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander  \
# 0                                                0.1
# 1                                                0.1
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                1.2
# 1                                                1.2
# 2                                                6.2
# 3                                                2.2
# 4                                               12.9
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                0.1
# 1                                                0.1
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                0.2
# 1                                                0.6
# 2                                                2.4
# 3                                                0.4
# 4                                                5.4
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race  \
# 0                                                0.1
# 1                                                0.2
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                1.5
# 1                                                7.9
# 2                                                3.0
# 3                                                2.0
# 4                                                4.3
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                0.1
# 1                                                0.2
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                0.8
# 1                                                2.4
# 2                                                1.0
# 3                                                1.1
# 4                                                1.9
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                0.1
# 1                                                0.3
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Year
# 0  2013
# 1  2013
# 2  2013
# 3  2013
# 4  2013
#
# [5 rows x 34 columns]

# %%
total_demo_state_df.columns
# Out:
# Index(['Geography',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - White',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - White',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - American Indian and Alaska Native',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Asian',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Native Hawaiian and Other Pacific Islander',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - Some other race',
#        'Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races',
#        'Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races',
#        '60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races',
#        '60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races',
#        'Year'],
#       dtype='object')

# %%
# Pass sheet title to description & country to hierachy columns for each row
total_demo_state_df["Hierarchy"] = "State"
# state_df["H_Name"] = list(state_df)[2]
# state_df["Population_Number"] = list(state_df)[3]
total_demo_state_df["Category"] = "Ethnicity"
total_demo_state_df["SubCategory"] = "White"
total_demo_state_df["Description"] = "Percentage"
total_demo_state_df["Notes"] = ""

# Rename 1st two columns
mapping = {state_df.columns[0]: 'H_Name', total_dstate_df.columns[5]: 'Population_Number'}
state_df = state_df.rename(columns=mapping)

state_df.head()
# Out:
#        H_Name  Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0     Alabama                                               98.5
# 1      Alaska                                               92.1
# 2     Arizona                                               97.0
# 3    Arkansas                                               98.0
# 4  California                                               95.7
#
#    Population_Number  \
# 0                0.1
# 1                0.2
# 2                0.1
# 3                0.1
# 4                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0                                               99.2
# 1                                               97.6
# 2                                               99.0
# 3                                               98.9
# 4                                               98.1
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race  \
# 0                                                0.1
# 1                                                0.3
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Population_Number  Population_Number  \
# 0               69.3                0.1
# 1               66.9                0.1
# 2               79.2                0.2
# 3               78.3                0.1
# 4               62.3                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                               78.9
# 1                                               76.8
# 2                                               90.1
# 3                                               87.6
# 4                                               72.6
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - One race - White  \
# 0                                                0.1
# 1                                                0.4
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - One race - Black or African American  \
# 0                                               26.3
# 1                                                3.5
# 2                                                4.2
# 3                                               15.5
# 4                                                6.0
#
#    ...    \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Total; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                1.5
# 1                                                7.9
# 2                                                3.0
# 3                                                2.0
# 4                                                4.3
#
#    Total; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                0.1
# 1                                                0.2
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    60 years and over; Estimate; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                0.8
# 1                                                2.4
# 2                                                1.0
# 3                                                1.1
# 4                                                1.9
#
#    60 years and over; Margin of Error; RACE AND HISPANIC OR LATINO ORIGIN - Two or more races  \
# 0                                                0.1
# 1                                                0.3
# 2                                                0.1
# 3                                                0.1
# 4                                                0.1
#
#    Year  Hierarchy   Category  SubCategory  Description  Notes
# 0  2013      State  Ethnicity        White   Percentage
# 1  2013      State  Ethnicity        White   Percentage
# 2  2013      State  Ethnicity        White   Percentage
# 3  2013      State  Ethnicity        White   Percentage
# 4  2013      State  Ethnicity        White   Percentage
#
# [5 rows x 39 columns]

# %%
final_state_df = state_df[['Year', 'Hierarchy', 'H_Name', 'Population_Number', 'Category', 'SubCategory', 'Description', 'Notes']]
final_state_df.head()
# Out:
#    Year Hierarchy      H_Name  Population_Number   Category SubCategory  \
# 0  2013     State     Alabama                0.1  Ethnicity       White
# 1  2013     State      Alaska                0.2  Ethnicity       White
# 2  2013     State     Arizona                0.1  Ethnicity       White
# 3  2013     State    Arkansas                0.1  Ethnicity       White
# 4  2013     State  California                0.1  Ethnicity       White
#
#   Description Notes
# 0  Percentage
# 1  Percentage
# 2  Percentage
# 3  Percentage
# 4  Percentage

# %%
# This function move footnotes to specific cells and remove Nan rows
def Update_FootNotes(_df):
    _df["Notes"] = "" 
    # Get all the 1st character in column, extract only digit & get the max    
    nlist = _df['Notes'].str[0].tolist()
    results = [int(n) for n in nlist if n.isdigit()]
    m = max(results)
    f = m
    # Loop thru the max and update footnote to specific row cell
    for i in range(m):
        n = (i+1)
        fn = f'-{f}'
        #         print(n)
        #         print(fn)
        footnote = _df.iloc[int(fn), 0].replace(f"{n} ", "")
#         print(footnote)
        _df.loc[_df.Notes.str.contains(str(n)), "Notes"] = f'Footnotes {n}: {footnote}'
        f-=1
    # -----------------------------------------------    
    # Drop all NaN rows
    _df = _df.dropna()
    # Remove digit from column
    pattern = '[0-9]'
    _df.Notes = [re.sub(pattern, '', row.Notes) for i, row in _df.iterrows()] 
        
    return _df

# %%
# Pass footnote to specific cells and clean data
# state_df = Update_FootNotes(state_df)
# Convert Column to Integer
# state_df[""] = state_df[""].astype(int)
# Some excel sheet has lowercase
# state_df.loc[state_df[""] == "", ""] = ""
# state_df.reset_index(drop=True,inplace=True)

# %%
final_state_df["Created_By"] = "Charleen"
final_state_df["Created_Date"] = pd.datetime.now().strftime("%m-%d-%Y %I:%M:%S")
final_state_df.head()
# Out:
#    Year Hierarchy      H_Name  Population_Number   Category SubCategory  \
# 0  2013     State     Alabama                0.1  Ethnicity       White
# 1  2013     State      Alaska                0.2  Ethnicity       White
# 2  2013     State     Arizona                0.1  Ethnicity       White
# 3  2013     State    Arkansas                0.1  Ethnicity       White
# 4  2013     State  California                0.1  Ethnicity       White
#
#   Description Notes Created_By         Created_Date
# 0  Percentage         Charleen  05-07-2019 06:27:15
# 1  Percentage         Charleen  05-07-2019 06:27:15
# 2  Percentage         Charleen  05-07-2019 06:27:15
# 3  Percentage         Charleen  05-07-2019 06:27:15
# 4  Percentage         Charleen  05-07-2019 06:27:15

# %%
# # Create notes column and copy footnotes to Notes for selective row by locating the row cell with the footnote
# country_df["Notes"] = ""      
# country_df.loc[country_df.Crime_Type.str.contains('1'), "Notes"] = f'Footnotes: {country_df.iloc[-2, 0].replace("1 ", "")}'
# country_df.loc[country_df.Crime_Type.str.contains('2'), "Notes"] = f'Footnotes: {country_df.iloc[-1, 0].replace("2 ", "")}'
# # Drop all NaN rows
# country_df = country_df.dropna()
# # Remove digit from column
# pattern = '[0-9]'
# country_df.Crime_Type = [re.sub(pattern, '', row.Crime_Type) for i, row in country_df.iterrows()] 
final_state_df.count()
# Out:
# Year                 51
# Hierarchy            51
# H_Name               51
# Population_Number    51
# Category             51
# SubCategory          51
# Description          51
# Notes                51
# Created_By           51
# Created_Date         51
# dtype: int64

# %%
final_state_df.dtypes
# Out:
# Year                  object
# Hierarchy             object
# H_Name                object
# Population_Number    float64
# Category              object
# SubCategory           object
# Description           object
# Notes                 object
# Created_By            object
# Created_Date          object
# dtype: object

# %%
final_state_df['Year'] = final_state_df['Year'].astype(int)

# %%
final_state_df = final_state_df.astype({'Year': 'int64'})

# %%
final_state_df.dtypes
# Out:
# Year                   int64
# Hierarchy             object
# H_Name                object
# Population_Number    float64
# Category              object
# SubCategory           object
# Description           object
# Notes                 object
# Created_By            object
# Created_Date          object
# dtype: object

# %%
final_state_df['H_Name'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
len(final_state_df['H_Name'].unique())
# Out:
# 51

# %%
final_state_df.shape
# Out:
# (51, 10)

# %%
final_state_df.describe()
# Out:
#          Year  Population_Number
# count    51.0          51.000000
# mean   2017.0          96.623529
# std       0.0           3.203660
# min    2017.0          76.200000
# 25%    2017.0          96.850000
# 50%    2017.0          97.400000
# 75%    2017.0          97.700000
# max    2017.0          98.700000

# %%
# Set connection to database
client = MongoClient("mongodb+srv://admin:admin123@janie-test-vcn3t.mongodb.net/test?retryWrites=true")
db = client.consultant

# %%
records = final_state_df.to_dict('records')
[db.population.update_many({"Year": row["Year"], "Hierarchy": row["Hierarchy"], "H_Name": row["H_Name"], "Population_Number": row["Population_Number"], "Category": row["Category"], "SubCategory": row["SubCategory"], "Description": row["Description"], "Notes": row["Notes"], "Created_By": row["Created_By"], "Created_Date": row["Created_Date"]}, {'$set': row}, upsert=True) for row in records]
# Out:
# [<pymongo.results.UpdateResult at 0x1c2e8d43e48>,
#  <pymongo.results.UpdateResult at 0x1c2e8e0ddc8>,
#  <pymongo.results.UpdateResult at 0x1c2e8d9fa08>,
#  <pymongo.results.UpdateResult at 0x1c2e8dee388>,
#  <pymongo.results.UpdateResult at 0x1c2e8df41c8>,
#  <pymongo.results.UpdateResult at 0x1c2e8e09248>,
#  <pymongo.results.UpdateResult at 0x1c2e8e09848>,
#  <pymongo.results.UpdateResult at 0x1c2e8e09b88>,
#  <pymongo.results.UpdateResult at 0x1c2e8d451c8>,
#  <pymongo.results.UpdateResult at 0x1c2e8df4ec8>,
#  <pymongo.results.UpdateResult at 0x1c2e8dfd288>,
#  <pymongo.results.UpdateResult at 0x1c2e8df5588>,
#  <pymongo.results.UpdateResult at 0x1c2e8df5888>,
#  <pymongo.results.UpdateResult at 0x1c2e8df97c8>,
#  <pymongo.results.UpdateResult at 0x1c2e8df9808>,
#  <pymongo.results.UpdateResult at 0x1c2e8dab4c8>,
#  <pymongo.results.UpdateResult at 0x1c2e8de5488>,
#  <pymongo.results.UpdateResult at 0x1c2e8de5408>,
#  <pymongo.results.UpdateResult at 0x1c2e8de79c8>,
#  <pymongo.results.UpdateResult at 0x1c2e8de7e88>,
#  <pymongo.results.UpdateResult at 0x1c2e8df0d48>,
#  <pymongo.results.UpdateResult at 0x1c2e8df0888>,
#  <pymongo.results.UpdateResult at 0x1c2e8de1c48>,
#  <pymongo.results.UpdateResult at 0x1c2e8dff6c8>,
#  <pymongo.results.UpdateResult at 0x1c2e8dff688>,
#  <pymongo.results.UpdateResult at 0x1c2e8e02888>,
#  <pymongo.results.UpdateResult at 0x1c2e8e02e48>,
#  <pymongo.results.UpdateResult at 0x1c2e8db1048>,
#  <pymongo.results.UpdateResult at 0x1c2e8db1648>,
#  <pymongo.results.UpdateResult at 0x1c2e8e38188>,
#  <pymongo.results.UpdateResult at 0x1c2e8e38e48>,
#  <pymongo.results.UpdateResult at 0x1c2e8e3b1c8>,
#  <pymongo.results.UpdateResult at 0x1c2e8e3bd48>,
#  <pymongo.results.UpdateResult at 0x1c2e8e1cb48>,
#  <pymongo.results.UpdateResult at 0x1c2e8e1c988>,
#  <pymongo.results.UpdateResult at 0x1c2e8e3dbc8>,
#  <pymongo.results.UpdateResult at 0x1c2e8e3df08>,
#  <pymongo.results.UpdateResult at 0x1c2e8e41708>,
#  <pymongo.results.UpdateResult at 0x1c2e8e41a48>,
#  <pymongo.results.UpdateResult at 0x1c2e8e436c8>,
#  <pymongo.results.UpdateResult at 0x1c2e8e43548>,
#  <pymongo.results.UpdateResult at 0x1c2e8e47848>,
#  <pymongo.results.UpdateResult at 0x1c2e8e47ec8>,
#  <pymongo.results.UpdateResult at 0x1c2e8e4a088>,
#  <pymongo.results.UpdateResult at 0x1c2e8e4ac88>,
#  <pymongo.results.UpdateResult at 0x1c2e8e4c248>,
#  <pymongo.results.UpdateResult at 0x1c2e8e4cc88>,
#  <pymongo.results.UpdateResult at 0x1c2e8e50288>,
#  <pymongo.results.UpdateResult at 0x1c2e8e50788>,
#  <pymongo.results.UpdateResult at 0x1c2e8e52088>,
#  <pymongo.results.UpdateResult at 0x1c2e8e52dc8>]

# %%
# Get data from mongo & convert back to dataframe
df = pd.DataFrame.from_records(db.population.find({}, {'_id': 0 }))
df
# Out:
#         Category Created_By         Created_Date Description  \
# 0     Population   Charleen  05-05-2019 08:11:08     Integer
# 1     Population   Charleen  05-05-2019 08:11:08     Integer
# 2     Population   Charleen  05-05-2019 08:11:08     Integer
# 3     Population   Charleen  05-05-2019 08:11:08     Integer
# 4     Population   Charleen  05-05-2019 08:11:08     Integer
# 5     Population   Charleen  05-05-2019 08:11:08     Integer
# 6     Population   Charleen  05-05-2019 08:11:08     Integer
# 7     Population   Charleen  05-05-2019 08:11:08     Integer
# 8     Population   Charleen  05-05-2019 08:11:08     Integer
# 9     Population   Charleen  05-05-2019 08:11:08     Integer
# 10    Population   Charleen  05-05-2019 08:11:08     Integer
# 11    Population   Charleen  05-05-2019 08:11:08     Integer
# 12    Population   Charleen  05-05-2019 08:11:08     Integer
# 13    Population   Charleen  05-05-2019 08:11:08     Integer
# 14    Population   Charleen  05-05-2019 08:11:08     Integer
# 15    Population   Charleen  05-05-2019 08:11:08     Integer
# 16    Population   Charleen  05-05-2019 08:11:08     Integer
# 17    Population   Charleen  05-05-2019 08:11:08     Integer
# 18    Population   Charleen  05-05-2019 08:11:08     Integer
# 19    Population   Charleen  05-05-2019 08:11:08     Integer
# 20    Population   Charleen  05-05-2019 08:11:08     Integer
# 21    Population   Charleen  05-05-2019 08:11:08     Integer
# 22    Population   Charleen  05-05-2019 08:11:08     Integer
# 23    Population   Charleen  05-05-2019 08:11:08     Integer
# 24    Population   Charleen  05-05-2019 08:11:08     Integer
# 25    Population   Charleen  05-05-2019 08:11:08     Integer
# 26    Population   Charleen  05-05-2019 08:11:08     Integer
# 27    Population   Charleen  05-05-2019 08:11:08     Integer
# 28    Population   Charleen  05-05-2019 08:11:08     Integer
# 29    Population   Charleen  05-05-2019 08:11:08     Integer
# ...          ...        ...                  ...         ...
# 3897   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3898   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3899   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3900   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3901   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3902   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3903   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3904   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3905   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3906   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3907   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3908   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3909   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3910   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3911   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3912   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3913   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3914   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3915   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3916   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3917   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3918   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3919   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3920   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3921   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3922   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3923   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3924   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3925   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
# 3926   Ethnicity   Charleen  05-07-2019 06:20:18  Percentage
#
#                     H_Name Hierarchy Notes  Population_Number SubCategory  \
# 0                  Alabama     State                4633360.0       Total
# 1                   Alaska     State                 683142.0       Total
# 2                  Arizona     State                6324865.0       Total
# 3                 Arkansas     State                2838143.0       Total
# 4               California     State               36308527.0       Total
# 5                 Colorado     State                4843211.0       Total
# 6              Connecticut     State                3494487.0       Total
# 7                 Delaware     State                 863832.0       Total
# 8     District of Columbia     State                 588433.0       Total
# 9                  Florida     State               18222420.0       Total
# 10                 Georgia     State                9497667.0       Total
# 11                  Hawaii     State                1280241.0       Total
# 12                   Idaho     State                1492573.0       Total
# 13                Illinois     State               12785043.0       Total
# 14                 Indiana     State                6342469.0       Total
# 15                    Iowa     State                2978880.0       Total
# 16                  Kansas     State                2777835.0       Total
# 17                Kentucky     State                4252000.0       Total
# 18               Louisiana     State                4411546.0       Total
# 19                   Maine     State                1316380.0       Total
# 20                Maryland     State                5637418.0       Total
# 21           Massachusetts     State                6511176.0       Total
# 22                Michigan     State               10039208.0       Total
# 23               Minnesota     State                5188581.0       Total
# 24             Mississippi     State                2922240.0       Total
# 25                Missouri     State                5904382.0       Total
# 26                 Montana     State                 956257.0       Total
# 27                Nebraska     State                1772124.0       Total
# 28                  Nevada     State                2545763.0       Total
# 29           New Hampshire     State                1315419.0       Total
# ...                    ...       ...   ...                ...         ...
# 3897         Massachusetts     State                     96.9       Total
# 3898              Michigan     State                     97.2       Total
# 3899             Minnesota     State                     97.2       Total
# 3900           Mississippi     State                     98.7       Total
# 3901              Missouri     State                     97.5       Total
# 3902               Montana     State                     97.2       Total
# 3903              Nebraska     State                     97.6       Total
# 3904                Nevada     State                     95.3       Total
# 3905         New Hampshire     State                     98.0       Total
# 3906            New Jersey     State                     97.4       Total
# 3907            New Mexico     State                     96.7       Total
# 3908              New York     State                     97.0       Total
# 3909        North Carolina     State                     97.5       Total
# 3910          North Dakota     State                     97.7       Total
# 3911                  Ohio     State                     97.3       Total
# 3912              Oklahoma     State                     92.2       Total
# 3913                Oregon     State                     95.4       Total
# 3914          Pennsylvania     State                     97.7       Total
# 3915          Rhode Island     State                     97.0       Total
# 3916        South Carolina     State                     97.9       Total
# 3917          South Dakota     State                     97.3       Total
# 3918             Tennessee     State                     97.9       Total
# 3919                 Texas     State                     97.4       Total
# 3920                  Utah     State                     97.2       Total
# 3921               Vermont     State                     98.1       Total
# 3922              Virginia     State                     96.5       Total
# 3923            Washington     State                     94.5       Total
# 3924         West Virginia     State                     98.3       Total
# 3925             Wisconsin     State                     97.7       Total
# 3926               Wyoming     State                     97.4       Total
#
#       Year
# 0     2009
# 1     2009
# 2     2009
# 3     2009
# 4     2009
# 5     2009
# 6     2009
# 7     2009
# 8     2009
# 9     2009
# 10    2009
# 11    2009
# 12    2009
# 13    2009
# 14    2009
# 15    2009
# 16    2009
# 17    2009
# 18    2009
# 19    2009
# 20    2009
# 21    2009
# 22    2009
# 23    2009
# 24    2009
# 25    2009
# 26    2009
# 27    2009
# 28    2009
# 29    2009
# ...    ...
# 3897  2017
# 3898  2017
# 3899  2017
# 3900  2017
# 3901  2017
# 3902  2017
# 3903  2017
# 3904  2017
# 3905  2017
# 3906  2017
# 3907  2017
# 3908  2017
# 3909  2017
# 3910  2017
# 3911  2017
# 3912  2017
# 3913  2017
# 3914  2017
# 3915  2017
# 3916  2017
# 3917  2017
# 3918  2017
# 3919  2017
# 3920  2017
# 3921  2017
# 3922  2017
# 3923  2017
# 3924  2017
# 3925  2017
# 3926  2017
#
# [3927 rows x 10 columns]

# %%
# db.population.drop()
